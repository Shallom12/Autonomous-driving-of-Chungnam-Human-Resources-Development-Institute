# %% [markdown]
# <a href="https://colab.research.google.com/github/Shallom12/Autonomous-driving-of-Chungnam-Human-Resources-Development-Institute/blob/main/7_1_autonomous_driving_coding_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1번문제
def init_sensors():
    sensors = {
        '앞': 15.0,
        '왼쪽': 15.0,
        '오른쪽': 15.0
    }
    return sensors
print(init_sensors())

#2번문제
x= 10
y= 5
# Define obstacles as a list of coordinate tuples
obstacles = [(10, 6), (10, 7), (10, 8), (9, 5), (8, 5), (7, 5)]
sensors = init_sensors()
def scan_front(x,y,obstacles,sensors):
    print('앞쪽 스캔 시작')
    if (x, y+1) in obstacles:
        print('앞쪽 1칸 장애물 발견')
        sensors['앞'] = 1.0
    elif (x, y+2) in obstacles:
        print('앞쪽 2칸 장애물 발견')
        sensors['앞'] = 2.0
    elif (x, y+3) in obstacles:
        print('앞쪽 3칸 장애물 발견')
        sensors['앞'] = 3.0
    else:
        print('앞쪽 장애물 없음')
        sensors['앞'] = 15.0
    return sensors
print('앞쪽 스캔 완료')
print(scan_front(x,y,obstacles,sensors))

#3번 문제
def scan_left(x,y,obstacles,sensors):
    print('왼쪽 스캔 시작')
    if (x-1, y) in obstacles:
        print('왼쪽 1칸 장애물 발견')
        sensors['왼쪽'] = 1.0
    elif (x-2, y) in obstacles:
        print('왼쪽 2칸 장애물 발견')
        sensors['왼쪽'] = 2.0
    elif (x-3, y) in obstacles:
        print('왼쪽 3칸 장애물 발견')
        sensors['왼쪽'] = 3.0
    else:
        print('왼쪽 장애물 없음')
        sensors['왼쪽'] = 15.0
    return sensors
print('왼쪽 스캔 완료')
print(scan_left(x,y,obstacles,sensors))

#4번 문제
def scan_light(x,y,obstacles,sensors):
    print('오른쪽 스캔 시작')
    if (x+1, y) in obstacles:
        print('오른쪽 1칸 장애물 발견')
        sensors['오른쪽'] = 1.0
    elif (x+2, y) in obstacles:
        print('오른쪽 2칸 장애물 발견')
        sensors['오른쪽'] = 2.0
    elif (x+3, y) in obstacles:
        print('오른쪽 3칸 장애물 발견')
        sensors['오른쪽'] = 3.0
    else:
        print('오른쪽 장애물 없음')
        sensors['오른쪽'] = 15.0
    return sensors
print('오른쪽 스캔 완료')
print(scan_light(x,y,obstacles,sensors))

#5번문제
def update_sensor_data(position, obstacles):
    print('함수시작')
    x = position[0]
    y = position[1]
    print('위치 추출 완료')
    print('현재',(x, y),'값')
    sensors = init_sensors()
    print('센서 초기화 완료')
    scan_front(x, y, obstacles, sensors)
    print('앞쪽 스캔 완료')
    scan_left(x, y, obstacles, sensors)
    print('왼쪽 스캔 완료')
    scan_light(x, y, obstacles, sensors)
    print('오른쪽 스캔 완료')
    return sensors
    print('최종센서 데이터 출력')
print(update_sensor_data((x, y), obstacles))
# Out:
# {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# 앞쪽 스캔 완료
# 앞쪽 스캔 시작
# 앞쪽 1칸 장애물 발견
# {'앞': 1.0, '왼쪽': 15.0, '오른쪽': 15.0}
# 왼쪽 스캔 완료
# 왼쪽 스캔 시작
# 왼쪽 1칸 장애물 발견
# {'앞': 1.0, '왼쪽': 1.0, '오른쪽': 15.0}
# 오른쪽 스캔 완료
# 오른쪽 스캔 시작
# 오른쪽 장애물 없음
# {'앞': 1.0, '왼쪽': 1.0, '오른쪽': 15.0}
# 함수시작
# 위치 추출 완료
# 현재 (10, 5) 값
# 센서 초기화 완료
# 앞쪽 스캔 시작
# 앞쪽 1칸 장애물 발견
# 앞쪽 스캔 완료
# 왼쪽 스캔 시작
# 왼쪽 1칸 장애물 발견
# 왼쪽 스캔 완료
# 오른쪽 스캔 시작
# 오른쪽 장애물 없음
# 오른쪽 스캔 완료
# {'앞': 1.0, '왼쪽': 1.0, '오른쪽': 15.0}

# %%
#1번문제
def init_sensors():
    sensors = {
        '앞': 15.0,
        '왼쪽': 15.0,
        '오른쪽': 15.0
    }
    return sensors
print(init_sensors())

#2번문제
x= 10
y= 5
# Define obstacles as a list of coordinate tuples
obstacles = [(10, 6), (10, 7), (10, 8), (9, 5), (8, 5), (7, 5)]
sensors = init_sensors()
def scan_front(x,y,obstacles,sensors):
    print('앞쪽 스캔 시작')
    if (x, y+1) in obstacles:
        print('앞쪽 1칸 장애물 발견')
        sensors['앞'] = 1.0
    elif (x, y+2) in obstacles:
        print('앞쪽 2칸 장애물 발견')
        sensors['앞'] = 2.0
    elif (x, y+3) in obstacles:
        print('앞쪽 3칸 장애물 발견')
        sensors['앞'] = 3.0
    else:
        print('앞쪽 장애물 없음')
        sensors['앞'] = 15.0
    return sensors
print('앞쪽 스캔 완료')
print(scan_front(x,y,obstacles,sensors))

#3번 문제
def scan_left(x,y,obstacles,sensors):
    print('왼쪽 스캔 시작')
    if (x-1, y) in obstacles:
        print('왼쪽 1칸 장애물 발견')
        sensors['왼쪽'] = 1.0
    elif (x-2, y) in obstacles:
        print('왼쪽 2칸 장애물 발견')
        sensors['왼쪽'] = 2.0
    elif (x-3, y) in obstacles:
        print('왼쪽 3칸 장애물 발견')
        sensors['왼쪽'] = 3.0
    else:
        print('왼쪽 장애물 없음')
        sensors['왼쪽'] = 15.0
    return sensors
print('왼쪽 스캔 완료')
print(scan_left(x,y,obstacles,sensors))

#4번 문제
def scan_light(x,y,obstacles,sensors):
    print('오른쪽 스캔 시작')
    if (x+1, y) in obstacles:
        print('오른쪽 1칸 장애물 발견')
        sensors['오른쪽'] = 1.0
    elif (x+2, y) in obstacles:
        print('오른쪽 2칸 장애물 발견')
        sensors['오른쪽'] = 2.0
    elif (x+3, y) in obstacles:
        print('오른쪽 3칸 장애물 발견')
        sensors['오른쪽'] = 3.0
    else:
        print('오른쪽 장애물 없음')
        sensors['오른쪽'] = 15.0
    return sensors
print('오른쪽 스캔 완료')
print(scan_light(x,y,obstacles,sensors))

#5번문제
def update_sensor_data(position, obstacles):
    print('함수시작')
    x = position[0]
    y = position[1]
    print('위치 추출 완료')
    print('현재',(x, y),'값')
    sensors = init_sensors()
    print('센서 초기화 완료')
    scan_front(x, y, obstacles, sensors)
    print('앞쪽 스캔 완료')
    scan_left(x, y, obstacles, sensors)
    print('왼쪽 스캔 완료')
    scan_light(x, y, obstacles, sensors)
    print('오른쪽 스캔 완료')
    return sensors
    print('최종센서 데이터 출력')
print(update_sensor_data((x, y), obstacles))

#6번 문제
safe_distance = 10.0
def detect_obstacles(sensors, safe_distance):
    print('함수시작')
    obstacles = []
    if sensors['앞'] < safe_distance:
        print('앞쪽 장애물 발견')
        obstacles.append('앞')
    elif sensors['왼쪽'] < safe_distance:
        print('왼쪽 장애물 발견')
        obstacles.append('왼쪽')
    elif sensors['오른쪽'] < safe_distance:
        print('오른쪽 장애물 발견')
        obstacles.append('오른쪽')
    else:
        print('장애물 없음')
    for direction, distance in sensors.items():
        if direction != '앞' and distance < safe_distance:
            print(f'{direction}위험')
            obstacles.append(direction)
        elif direction == '왼쪽' and distance < safe_distance:
            print('왼쪽 장애물 발견')
            obstacles.append('왼쪽')
        elif direction == '오른쪽' and distance < safe_distance:
            print('오른쪽 장애물 발견')
            obstacles.append('오른쪽')
        else:
            print('안전')
    return obstacles
print('장애물 감지 완료')

#7번문제
def decide_action():
    obstacles = detect_obstacles(sensors, safe_distance)
    if len(obstacles) == 0:
        action = '전진'
        print('장애물 없음')
    elif len(obstacles) != 0:
        action = '주의해서 직진'
        print('앞은 안전, 옆만 위험')
    elif '앞' in obstacles:
        print('앞쪽 장애물 발견, 좌우 확인')
    elif '왼쪽' not in obstacles:
        action = '좌회전'
        print('왼쪽 장애물 없음 안전')
    elif '오른쪽' not in obstacles:
        action = '우회전'
        print('오른쪽 장애물 없음 안전')
    else:
        action = '정지'
        print('모든 방향 위험')
        return action
print(decide_action())
# Out:
# {'앞': 15.0, '왼쪽': 15.0, '오른쪽': 15.0}
# 앞쪽 스캔 완료
# 앞쪽 스캔 시작
# 앞쪽 1칸 장애물 발견
# {'앞': 1.0, '왼쪽': 15.0, '오른쪽': 15.0}
# 왼쪽 스캔 완료
# 왼쪽 스캔 시작
# 왼쪽 1칸 장애물 발견
# {'앞': 1.0, '왼쪽': 1.0, '오른쪽': 15.0}
# 오른쪽 스캔 완료
# 오른쪽 스캔 시작
# 오른쪽 장애물 없음
# {'앞': 1.0, '왼쪽': 1.0, '오른쪽': 15.0}
# 함수시작
# 위치 추출 완료
# 현재 (10, 5) 값
# 센서 초기화 완료
# 앞쪽 스캔 시작
# 앞쪽 1칸 장애물 발견
# 앞쪽 스캔 완료
# 왼쪽 스캔 시작
# 왼쪽 1칸 장애물 발견
# 왼쪽 스캔 완료
# 오른쪽 스캔 시작
# 오른쪽 장애물 없음
# 오른쪽 스캔 완료
# {'앞': 1.0, '왼쪽': 1.0, '오른쪽': 15.0}
# 장애물 감지 완료
# 함수시작
# 앞쪽 장애물 발견
# 안전
# 왼쪽위험
# 안전
# 앞은 안전, 옆만 위험
# None

# %%
class SimpleCar:
    def __init__(name, x, y):
        start_position = position
        obstacles = obstacles
        name= 'BMW'
    def excute_action(action):
        def move_forward():
            print('전진')
        def turn_left():
            print('좌회전')
        def turn_right():
            print('우회전')
        def stop():
            print('정지')
