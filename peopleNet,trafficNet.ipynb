# %% [markdown]
# <a href="https://colab.research.google.com/github/Shallom12/Autonomous-driving-of-Chungnam-Human-Resources-Development-Institute/blob/main/peopleNet%2CtrafficNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 필요한 라이브러리 설치
# yt-dlp: YouTube 비디오 다운로드 (pytube 대체)
# ultralytics: YOLOv5 모델 사용
# opencv-python: 비디오 처리
# torch: 딥러닝 프레임워크
# !pip install yt-dlp ultralytics opencv-python torch

import cv2
import numpy as np
import yt_dlp
import torch
from ultralytics import YOLO
import os
from google.colab import files

# YouTube 비디오 다운로드 함수
def download_youtube_video(url, output_path):
    """
    주어진 YouTube URL에서 비디오를 다운로드하여 지정된 경로에 저장합니다.
    yt-dlp를 사용하여 안정적으로 다운로드합니다.

    Args:
        url (str): YouTube 비디오 URL
        output_path (str): 다운로드된 비디오를 저장할 경로
    Returns:
        str: 다운로드된 비디오 파일의 경로
    """
    try:
        # yt-dlp 옵션 설정
        ydl_opts = {
            'format': 'best[ext=mp4]',  # MP4 형식의 최고 품질 비디오 선택
            'outtmpl': os.path.join(output_path, 'input_video.mp4'),  # 출력 파일명
            'quiet': False,  # 진행 상황 출력
            'no_warnings': True,  # 경고 메시지 억제
        }

        print(f"비디오 다운로드 중: {url}")
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info = ydl.extract_info(url, download=True)
            print(f"다운로드 완료: {info['title']}")
        return os.path.join(output_path, 'input_video.mp4')
    except Exception as e:
        print(f"비디오 다운로드 오류: {str(e)}")
        return None

# 비디오 처리 및 사람 감지 함수
def process_video(video_path, output_path, model):
    """
    비디오를 처리하여 사람을 감지하고, 결과를 저장합니다.

    Args:
        video_path (str): 입력 비디오 경로
        output_path (str): 출력 비디오 저장 경로
        model: 사람 감지를 위한 사전 학습된 모델 (YOLOv5)
    """
    # 비디오 열기
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("오류: 비디오를 열 수 없습니다.")
        return

    # 비디오 속성 가져오기
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    # 출력 비디오 설정 (코덱 및 파일 생성)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # 프레임을 RGB로 변환 (YOLOv5는 RGB 입력을 요구)
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # 사람 감지 수행
        results = model(frame_rgb)

        # 감지 결과 처리
        # YOLOv5 결과 형식 변경에 대한 처리
        # ultralytics 라이브러리의 YOLOv5 결과는 xyxy[0] 대신 results[0].boxes.data를 사용합니다.
        if results and results[0].boxes:
            for detection in results[0].boxes.data:  # [x1, y1, x2, y2, 신뢰도, 클래스]
                if int(detection[5]) == 0:  # YOLOv5에서 클래스 0은 'person'
                    x1, y1, x2, y2 = map(int, detection[:4])
                    confidence = detection[4]
                    if confidence > 0.5:  # 신뢰도 임계값
                        # 바운딩 박스와 라벨 그리기
                        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                        cv2.putText(frame, f'사람 {confidence:.2f}', (x1, y1-10),
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)


        # 처리된 프레임을 출력 비디오에 저장
        out.write(frame)

    # 자원 해제
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"처리된 비디오가 {output_path}에 저장되었습니다.")

# 메인 실행 함수
def main():
    # 경로 설정
    video_url = "https://youtu.be/KoRmB706ZTA?si=Et_huXMkr3L7d_tT"
    output_dir = "/content"
    output_video_path = "/content/output_video.mp4"

    # 출력 디렉토리 생성
    os.makedirs(output_dir, exist_ok=True)

    # YouTube 비디오 다운로드
    video_path = download_youtube_video(video_url, output_dir)

    # 비디오 다운로드 성공 여부 확인 후 처리 진행
    if video_path and os.path.exists(video_path):
        # YOLOv5 모델 로드 (Colab에서 빠른 추론을 위해 'yolov5s' 사용)
        print("YOLOv5 모델 로드 중...")
        model = YOLO('yolov5s.pt')  # 사전 학습된 YOLOv5 소형 모델

        # 비디오 처리
        print("사람 감지를 위해 비디오 처리 중...")
        process_video(video_path, output_video_path, model)

        # 처리된 비디오 다운로드 (파일이 존재하는 경우에만 시도)
        if os.path.exists(output_video_path):
            print("처리된 비디오 다운로드 중...")
            files.download(output_video_path)
        else:
            print("오류: 처리된 비디오 파일을 찾을 수 없어 다운로드할 수 없습니다.")
    else:
        print("YouTube 비디오 다운로드에 실패하여 처리를 진행할 수 없습니다.")


if __name__ == "__main__":
    main()
# Out:
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.11/dist-packages (2025.7.21)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.170)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.12.0.88)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cpu)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.16.0)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cpu)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.7.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.7.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# 비디오 다운로드 중: https://youtu.be/KoRmB706ZTA?si=Et_huXMkr3L7d_tT
# [youtube] Extracting URL: https://youtu.be/KoRmB706ZTA?si=Et_huXMkr3L7d_tT
# [youtube] KoRmB706ZTA: Downloading webpage
# [youtube] KoRmB706ZTA: Downloading tv client config
# [youtube] KoRmB706ZTA: Downloading player 0b00c3eb-main
# [youtube] KoRmB706ZTA: Downloading tv player API JSON
# [youtube] KoRmB706ZTA: Downloading ios player API JSON
# [youtube] KoRmB706ZTA: Downloading m3u8 information
# [info] KoRmB706ZTA: Downloading 1 format(s): 18
# [download] /content/input_video.mp4 has already been downloaded
# [download] 100% of    3.49MiB
# 다운로드 완료: “지하철 9호선, 출근 시간대 운행 횟수 늘릴 것” / KBS  2023.07.31.
# YOLOv5 모델 로드 중...
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# 사람 감지를 위해 비디오 처리 중...
#
# 0: 384x640 8 persons, 2 ties, 1 laptop, 1 mouse, 165.2ms
# Speed: 1.2ms preprocess, 165.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 ties, 1 laptop, 1 mouse, 115.3ms
# Speed: 1.6ms preprocess, 115.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.9ms
# Speed: 1.5ms preprocess, 166.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 113.7ms
# Speed: 1.3ms preprocess, 113.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.6ms
# Speed: 1.5ms preprocess, 167.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 110.9ms
# Speed: 1.6ms preprocess, 110.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.3ms
# Speed: 1.1ms preprocess, 165.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 113.9ms
# Speed: 1.6ms preprocess, 113.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 203.5ms
# Speed: 69.8ms preprocess, 203.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 189.9ms
# Speed: 1.7ms preprocess, 189.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 116.1ms
# Speed: 1.4ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.7ms
# Speed: 1.5ms preprocess, 165.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 116.1ms
# Speed: 1.5ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 207.4ms
# Speed: 1.5ms preprocess, 207.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 193.7ms
# Speed: 1.1ms preprocess, 193.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 114.3ms
# Speed: 1.1ms preprocess, 114.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.9ms
# Speed: 1.4ms preprocess, 168.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 114.5ms
# Speed: 1.5ms preprocess, 114.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 205.8ms
# Speed: 57.7ms preprocess, 205.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 192.5ms
# Speed: 1.4ms preprocess, 192.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 115.5ms
# Speed: 1.3ms preprocess, 115.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.8ms
# Speed: 1.5ms preprocess, 167.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 112.1ms
# Speed: 1.5ms preprocess, 112.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 174.0ms
# Speed: 1.4ms preprocess, 174.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons,
3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 chair, 1 toilet, 113.1ms
# Speed: 1.4ms preprocess, 113.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 backpack, 168.1ms
# Speed: 1.3ms preprocess, 168.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 backpack, 2 chairs, 114.3ms
# Speed: 1.4ms preprocess, 114.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 backpack, 1 suitcase, 1 chair, 169.2ms
# Speed: 1.1ms preprocess, 169.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 backpack, 1 suitcase, 1 chair, 115.4ms
# Speed: 1.3ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 backpack, 115.7ms
# Speed: 52.9ms preprocess, 115.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 suitcase, 113.4ms
# Speed: 1.3ms preprocess, 113.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 backpack, 1 suitcase, 170.5ms
# Speed: 1.1ms preprocess, 170.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 dog, 1 backpack, 1 suitcase, 115.8ms
# Speed: 1.4ms preprocess, 115.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 backpack, 1 suitcase, 112.8ms
# Speed: 1.6ms preprocess, 112.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 dog, 1 backpack, 1 suitcase, 115.1ms
# Speed: 1.4ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 dog, 2 backpacks, 1 suitcase, 112.0ms
# Speed: 1.4ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 dog, 1 backpack, 1 suitcase, 115.8ms
# Speed: 1.4ms preprocess, 115.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 dog, 1 backpack, 1 suitcase, 119.5ms
# Speed: 1.4ms preprocess, 119.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 backpack, 2 chairs, 172.5ms
# Speed: 1.4ms preprocess, 172.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 backpack, 1 chair, 115.3ms
# Speed: 1.5ms preprocess, 115.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 chair, 168.0ms
# Speed: 1.4ms preprocess, 168.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 chair, 115.4ms
# Speed: 1.2ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 chair, 117.8ms
# Speed: 53.9ms preprocess, 117.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 dog, 1 chair, 115.9ms
# Speed: 1.5ms preprocess, 115.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 chair, 114.1ms
# Speed: 1.1ms preprocess, 114.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 chair, 171.0ms
# Speed: 1.3ms preprocess, 171.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 chair, 1 tv, 115.5ms
# Speed: 1.5ms preprocess, 115.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 suitcases, 1 chair, 171.0ms
# Speed: 1.4ms preprocess, 171.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 suitcase, 1 chair, 116.5ms
# Speed: 1.4ms preprocess, 116.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 chair, 169.1ms
# Speed: 1.3ms preprocess, 169.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 handbag, 1 chair, 111.2ms
# Speed: 1.1ms preprocess, 111.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 chair, 168.2ms
# Speed: 1.3ms preprocess, 168.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 handbag, 1 chair, 114.4ms
# Speed: 1.5ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 handbag, 1 chair, 167.1ms
# Speed: 1.4ms preprocess, 167.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 chair, 115.6ms
# Speed: 1.4ms preprocess, 115.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 chair, 114.8ms
# Speed: 1.4ms preprocess, 114.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 suitcase, 1 chair, 113.5ms
# Speed: 1.4ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 suitcase, 1 chair, 113.5ms
# Speed: 51.5ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 chair, 113.5ms
# Speed: 1.3ms preprocess, 113.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 suitcase, 1 chair, 114.8ms
# Speed: 54.6ms preprocess, 114.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 chair, 113.2ms
# Speed: 1.3ms preprocess, 113.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 chairs, 115.0ms
# Speed: 52.8ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 chair, 114.6ms
# Speed: 1.3ms preprocess, 114.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 chair, 109.2ms
# Speed: 53.1ms preprocess, 109.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 chairs, 114.6ms
# Speed: 1.7ms preprocess, 114.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 chair, 169.5ms
# Speed: 1.4ms preprocess, 169.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 chair, 114.4ms
# Speed: 1.4ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 chair, 1 tv, 113.5ms
# Speed: 54.8ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 backpack, 1 handbag, 111.4ms
# Speed: 1.1ms preprocess, 111.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 suitcase, 170.0ms
# Speed: 1.5ms preprocess, 170.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 suitcases, 112.9ms
# Speed: 1.5ms preprocess, 112.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 suitcase, 110.7ms
# Speed: 54.0ms preprocess, 110.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 chair, 115.1ms
# Speed: 1.4ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 suitcase, 169.2ms
# Speed: 1.5ms preprocess, 169.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1
2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 handbags, 1 chair, 110.9ms
# Speed: 1.4ms preprocess, 110.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 3 handbags, 113.9ms
# Speed: 53.6ms preprocess, 113.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 3 handbags, 109.5ms
# Speed: 1.4ms preprocess, 109.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 3 handbags, 166.9ms
# Speed: 1.4ms preprocess, 166.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 handbags, 113.5ms
# Speed: 1.3ms preprocess, 113.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 3 handbags, 166.3ms
# Speed: 1.4ms preprocess, 166.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 4 handbags, 114.4ms
# Speed: 1.0ms preprocess, 114.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 4 handbags, 169.3ms
# Speed: 1.4ms preprocess, 169.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 3 handbags, 111.8ms
# Speed: 1.3ms preprocess, 111.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 3 handbags, 166.9ms
# Speed: 1.4ms preprocess, 166.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 3 handbags, 1 suitcase, 114.3ms
# Speed: 1.3ms preprocess, 114.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 3 handbags, 1 suitcase, 1 chair, 167.0ms
# Speed: 1.4ms preprocess, 167.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 3 handbags, 114.8ms
# Speed: 1.4ms preprocess, 114.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 handbags, 167.6ms
# Speed: 1.4ms preprocess, 167.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 2 handbags, 113.8ms
# Speed: 1.3ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 handbags, 165.8ms
# Speed: 1.5ms preprocess, 165.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 2 handbags, 1 suitcase, 114.0ms
# Speed: 1.3ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 3 handbags, 1 chair, 168.5ms
# Speed: 1.4ms preprocess, 168.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 3 handbags, 118.6ms
# Speed: 1.4ms preprocess, 118.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 3 handbags, 118.1ms
# Speed: 51.1ms preprocess, 118.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 handbags, 116.6ms
# Speed: 1.4ms preprocess, 116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 handbags, 113.9ms
# Speed: 1.4ms preprocess, 113.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 3 handbags, 114.1ms
# Speed: 1.4ms preprocess, 114.1ms inference, 54.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 handbags, 113.3ms
# Speed: 1.4ms preprocess, 113.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 handbags, 172.5ms
# Speed: 1.4ms preprocess, 172.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 4 handbags, 120.8ms
# Speed: 1.4ms preprocess, 120.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 4 handbags, 119.1ms
# Speed: 52.8ms preprocess, 119.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 114.7ms
# Speed: 1.1ms preprocess, 114.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 119.8ms
# Speed: 1.4ms preprocess, 119.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 172.4ms
# Speed: 1.5ms preprocess, 172.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 114.4ms
# Speed: 1.1ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 165.4ms
# Speed: 1.4ms preprocess, 165.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 117.3ms
# Speed: 1.4ms preprocess, 117.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 170.0ms
# Speed: 1.6ms preprocess, 170.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 115.7ms
# Speed: 1.2ms preprocess, 115.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 114.6ms
# Speed: 1.4ms preprocess, 114.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 chair, 172.9ms
# Speed: 1.4ms preprocess, 172.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 chair, 117.6ms
# Speed: 1.4ms preprocess, 117.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 167.7ms
# Speed: 1.4ms preprocess, 167.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 116.6ms
# Speed: 1.5ms preprocess, 116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 169.0ms
# Speed: 1.2ms preprocess, 169.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 115.8ms
# Speed: 1.6ms preprocess, 115.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 laptop, 116.0ms
# Speed: 52.2ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 chair, 1 laptop, 114.2ms
# Speed: 1.4ms preprocess, 114.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 chair, 115.8ms
# Speed: 50.7ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 chairs, 116.5ms
# Speed: 1.4ms preprocess, 116.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 117.7ms
# Speed: 1.6ms preprocess, 117.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 167.5ms
# Speed: 1.5ms preprocess, 167.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 113.5ms
# Speed: 1.4ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 168.8ms
# Speed: 1.4ms preprocess, 168.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 114.8ms
# Speed: 1.5ms preprocess, 114.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 167.3ms
# Speed: 1.1ms preprocess, 167.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 laptop, 113.7ms
# Speed: 1.3ms preprocess, 113.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 170.1ms
# Speed: 1.3ms preprocess, 170.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons,
ms preprocess, 112.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 112.9ms
# Speed: 1.4ms preprocess, 112.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 113.9ms
# Speed: 54.4ms preprocess, 113.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 114.6ms
# Speed: 1.4ms preprocess, 114.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 165.1ms
# Speed: 1.0ms preprocess, 165.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 111.1ms
# Speed: 1.3ms preprocess, 111.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 111.3ms
# Speed: 1.1ms preprocess, 111.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 처리된 비디오가 /content/output_video.mp4에 저장되었습니다.
# 처리된 비디오 다운로드 중...

# %%
# 필요한 라이브러리 설치
# yt-dlp: YouTube 비디오 다운로드
# ultralytics: YOLOv5 모델 사용
# opencv-python: 비디오 처리
# torch: 딥러닝 프레임워크
# pillow: 한글 텍스트 렌더링
# !pip install yt-dlp ultralytics opencv-python torch pillow

import cv2
import numpy as np
import yt_dlp
import torch
from ultralytics import YOLO
import os
from google.colab import files
from PIL import Image, ImageDraw, ImageFont

# YouTube 비디오 다운로드 함수
def download_youtube_video(url, output_path):
    """
    주어진 YouTube URL에서 비디오를 다운로드하여 지정된 경로에 저장합니다.
    yt-dlp를 사용하여 안정적으로 다운로드합니다.

    Args:
        url (str): YouTube 비디오 URL
        output_path (str): 다운로드된 비디오를 저장할 경로
    Returns:
        str: 다운로드된 비디오 파일의 경로
    """
    try:
        # yt-dlp 옵션 설정
        ydl_opts = {
            'format': 'best[ext=mp4]',  # MP4 형식의 최고 품질 비디오 선택
            'outtmpl': os.path.join(output_path, 'input_video.mp4'),  # 출력 파일명
            'quiet': False,  # 진행 상황 출력
            'no_warnings': True,  # 경고 메시지 억제
        }

        print(f"비디오 다운로드 중: {url}")
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info = ydl.extract_info(url, download=True)
            print(f"다운로드 완료: {info['title']}")
        return os.path.join(output_path, 'input_video.mp4')
    except Exception as e:
        print(f"비디오 다운로드 오류: {str(e)}")
        return None

# 한글 텍스트를 프레임에 추가하는 함수
def draw_text_pil(frame, text, position, font_path="/usr/share/fonts/truetype/noto/NotoSansCJK-Regular.ttc", font_size=20):
    """
    PIL을 사용하여 OpenCV 프레임에 한글 텍스트를 그립니다.

    Args:
        frame: OpenCV 프레임 (numpy 배열)
        text: 그릴 텍스트 (예: "사람 0.95")
        position: 텍스트 위치 (x, y)
        font_path: 한글 폰트 파일 경로
        font_size: 폰트 크기
    Returns:
        frame: 텍스트가 추가된 프레임
    """
    # OpenCV 프레임을 PIL 이미지로 변환
    frame_pil = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    draw = ImageDraw.Draw(frame_pil)

    # 폰트 로드
    try:
        font = ImageFont.truetype(font_path, font_size)
    except Exception as e:
        print(f"폰트 로드 오류: {e}. 기본 폰트 사용")
        font = ImageFont.load_default()

    # 텍스트 그리기
    draw.text(position, text, font=font, fill=(0, 255, 0, 255))  # 초록색 텍스트

    # PIL 이미지를 OpenCV 프레임으로 변환
    frame = cv2.cvtColor(np.array(frame_pil), cv2.COLOR_RGB2BGR)
    return frame

# 비디오 처리 및 사람 감지 함수
def process_video(video_path, output_path, model):
    """
    비디오를 처리하여 사람을 감지하고, 결과를 저장합니다.

    Args:
        video_path (str): 입력 비디오 경로
        output_path (str): 출력 비디오 저장 경로
        model: 사람 감지를 위한 사전 학습된 모델 (YOLOv5)
    """
    # 비디오 열기
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("오류: 비디오를 열 수 없습니다.")
        return

    # 비디오 속성 가져오기
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    # 출력 비디오 설정 (코덱 및 파일 생성)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # 프레임을 RGB로 변환 (YOLOv5는 RGB 입력을 요구)
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # 사람 감지 수행
        results = model(frame_rgb)

        # 감지 결과 처리
        if results and results[0].boxes:
            for detection in results[0].boxes.data:  # [x1, y1, x2, y2, 신뢰도, 클래스]
                class_id = int(detection[5])
                if class_id == 0:  # YOLOv5에서 클래스 0은 'person'
                    x1, y1, x2, y2 = map(int, detection[:4])
                    confidence = float(detection[4])
                    if confidence > 0.5:  # 신뢰도 임계값
                        # 바운딩 박스 그리기
                        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                        # 한글 라벨 추가 (PIL 사용)
                        label = f"사람 {confidence:.2f}"
                        frame = draw_text_pil(frame, label, (x1, y1-10))
                        # 디버깅용 출력
                        print(f"감지: 클래스={model.names[class_id]}, 신뢰도={confidence:.2f}, 좌표=({x1}, {y1}, {x2}, {y2})")

        # 처리된 프레임을 출력 비디오에 저장
        out.write(frame)

    # 자원 해제
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"처리된 비디오가 {output_path}에 저장되었습니다.")

# 메인 실행 함수
def main():
    # 경로 설정
    video_url = "https://youtu.be/KoRmB706ZTA?si=Et_huXMkr3L7d_tT"
    output_dir = "/content"
    output_video_path = "/content/output_video.mp4"

    # 출력 디렉토리 생성
    os.makedirs(output_dir, exist_ok=True)

    # YouTube 비디오 다운로드
    video_path = download_youtube_video(video_url, output_dir)

    # 비디오 다운로드 성공 여부 확인 후 처리 진행
    if video_path and os.path.exists(video_path):
        # YOLOv5 모델 로드 (Colab에서 빠른 추론을 위해 'yolov5s' 사용)
        print("YOLOv5 모델 로드 중...")
        model = YOLO('yolov5s.pt')  # 사전 학습된 YOLOv5 소형 모델

        # 클래스 이름 확인 (디버깅용)
        print(f"모델 클래스 이름: {model.names}")

        # 비디오 처리
        print("사람 감지를 위해 비디오 처리 중...")
        process_video(video_path, output_video_path, model)

        # 처리된 비디오 다운로드 (파일이 존재하는 경우에만 시도)
        if os.path.exists(output_video_path):
            print("처리된 비디오 다운로드 중...")
            files.download(output_video_path)
        else:
            print("오류: 처리된 비디오 파일을 찾을 수 없어 다운로드할 수 없습니다.")
    else:
        print("YouTube 비디오 다운로드에 실패하여 처리를 진행할 수 없습니다.")

if __name__ == "__main__":
    main()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 감지: 클래스=person, 신뢰도=0.59, 좌표=(130, 167, 266, 284)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.52, 좌표=(552, 248, 613, 329)
#
# 0: 384x640 13 persons, 164.4ms
# Speed: 1.4ms preprocess, 164.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.89, 좌표=(342, 123, 429, 282)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.83, 좌표=(362, 104, 566, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.74, 좌표=(246, 155, 329, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(4, 120, 131, 360)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(231, 104, 280, 234)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(299, 117, 349, 281)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.52, 좌표=(187, 126, 247, 246)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(325, 105, 374, 180)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(530, 159, 603, 241)
#
# 0: 384x640 16 persons, 108.2ms
# Speed: 1.2ms preprocess, 108.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.87, 좌표=(341, 124, 427, 282)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.77, 좌표=(361, 103, 571, 357)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.69, 좌표=(0, 121, 125, 349)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.64, 좌표=(242, 156, 324, 282)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(112, 175, 281, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.58, 좌표=(228, 106, 280, 263)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.55, 좌표=(181, 128, 241, 250)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(552, 247, 614, 359)
#
# 0: 384x640 16 persons, 114.4ms
# Speed: 1.4ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.86, 좌표=(341, 123, 426, 280)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.80, 좌표=(359, 103, 562, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.73, 좌표=

# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(194, 110, 247, 206)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(311, 120, 352, 191)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(145, 131, 213, 227)
#
# 0: 384x640 13 persons, 1 train, 1 handbag, 161.6ms
# Speed: 1.6ms preprocess, 161.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.84, 좌표=(316, 124, 395, 278)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.79, 좌표=(324, 102, 533, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.69, 좌표=(549, 243, 612, 329)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.67, 좌표=(192, 109, 245, 196)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(310, 120, 349, 193)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.60, 좌표=(261, 113, 321, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.57, 좌표=(94, 157, 180, 360)
#
# 0: 384x640 16 persons, 1 train, 2 handbags, 112.7ms
# Speed: 1.2ms preprocess, 112.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.84, 좌표=(315, 123, 394, 277)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.84, 좌표=(323, 102, 535, 357)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(259, 127, 321, 286)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(91, 158, 176, 360)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(191, 110, 244, 192)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(138, 130, 207, 277)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.55, 좌표=(308, 120, 343, 193)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(550, 244, 612, 359)
#
# 0: 384x640 13 persons, 1 train, 2 handbags, 116.9ms
# Speed: 1.1ms preprocess, 116.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.84, 좌표=(315, 123, 395, 277)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.82, 좌표=(325, 100, 537, 357)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.78, 좌표=(550, 247, 613, 360)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.74, 좌표=(91, 157, 176, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.68, 좌표=(259, 125, 320, 285)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.52, 좌표=(192, 109, 245, 186)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(138, 131, 207, 282)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(308, 119, 343, 192)
#
# 0: 384x640 11 persons, 1 train, 2 handbags, 159.1ms
# Speed: 1.4ms preprocess, 159.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.83, 좌표=(327, 100, 541, 357)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.83, 좌표=(315, 123, 397, 280)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.77, 좌표=(550, 246, 614, 360)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.73, 좌표=(92, 157, 175, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.71, 좌표=(259, 120, 320, 285)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.65, 좌표=(165, 176, 280, 359)
#
# 0: 384x640 14 persons, 1 train, 2 handbags, 109.9ms
# Speed: 1.1ms preprocess, 109.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.87, 좌표=(327, 97, 545, 357)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(315, 122, 405, 281)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.74, 좌표=(92, 156, 175, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(258, 121, 321, 285)
#
# 0: 384x640 12 persons, 1 train, 2 handbags, 114.8ms
# Speed: 1.4ms preprocess, 114.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.86, 좌표=(329, 97, 546, 357)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.78, 좌표=(315, 121, 399, 282)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.69, 좌표=(91, 156, 174, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.66, 좌표=(194, 107, 250, 232)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.59, 좌표=(257, 120, 318, 285)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.58, 좌표=(163, 175, 273, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.57, 좌표=(550, 246, 627, 360)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(0, 121, 63, 304)
#
# 0: 384x640 13 persons, 1 train, 1 handbag, 164.2ms
# Speed: 1.3ms preprocess, 164.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.86, 좌표=(330, 96, 552, 357)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.75, 좌표=(314, 120, 401, 282)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.74, 좌표=(196, 107, 251, 239)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(550, 245, 614, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.57, 좌표=(0, 120, 63, 302)
#
# 0: 384x640 15 persons, 1 train, 1 handbag, 112.6ms
# Speed: 1.3ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.82, 좌표=(333, 99, 545, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.80, 좌표=(314, 119, 402, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.77, 좌표=(551, 245, 613, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.72, 좌표=(160, 180, 267, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(197, 107, 251, 230)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.58, 좌표=(91, 156, 170, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.57, 좌표=(138, 160, 193, 250)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.55, 좌표=(0, 119, 65, 304)
#
# 0: 384x640 14 persons, 1 train, 1 handbag, 112.6ms
# Speed: 1.2ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.82, 좌표=(314, 118, 402, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.79, 좌표=(336, 99, 545, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.73, 좌표=(198, 105, 254, 256)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.73, 좌표=(159, 182, 261, 360)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.67, 좌표=(0, 118, 66, 305)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.57, 좌표=(91, 156, 168, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.54, 좌표=(137, 159, 191, 249)
#
# 0: 384x640 15 persons, 1 train, 1 handbag, 160.7ms
# Speed: 1.5ms preprocess, 160.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.83, 좌표=(338, 99, 544, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.80, 좌표=(312, 118, 400, 282)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.78, 좌표=(198, 106, 252, 258)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.62, 좌표=(157, 184, 257, 360)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(359, 122, 434, 276)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.59, 좌표=(0, 118, 66, 307)
#
# 0: 384x640 18 persons, 1 train, 1 handbag, 109.4ms
# Speed: 1.2ms preprocess, 109.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.81, 좌표=(309, 118, 398, 281)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.80, 좌표=(339, 99, 543, 357)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.77, 좌표=(196, 107, 252, 274)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(358, 121, 436, 275)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.55, 좌표=(580, 161, 639, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.55, 좌표=(150, 189, 248, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.50, 좌표=(389, 126, 421, 187)
#
# 0: 384x640 18 persons, 1 train, 2 handbags, 162.4ms
# Speed: 1.5ms preprocess, 162.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0

# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.66, 좌표=(554, 247, 613, 327)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.65, 좌표=(127, 124, 204, 282)
#
# 0: 384x640 11 persons, 1 train, 2 handbags, 110.8ms
# Speed: 1.5ms preprocess, 110.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.78, 좌표=(384, 113, 539, 282)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(330, 118, 424, 281)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.75, 좌표=(279, 109, 337, 285)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.75, 좌표=(51, 149, 160, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.69, 좌표=(217, 95, 299, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.64, 좌표=(129, 124, 207, 282)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(554, 247, 614, 327)
#
# 0: 384x640 12 persons, 1 train, 2 handbags, 107.0ms
# Speed: 1.3ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.81, 좌표=(385, 112, 539, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.79, 좌표=(333, 116, 426, 280)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(277, 109, 337, 284)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(51, 150, 160, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(218, 94, 300, 284)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.67, 좌표=(129, 125, 209, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.65, 좌표=(553, 246, 613, 327)
#
# 0: 384x640 13 persons, 1 train, 1 handbag, 164.7ms
# Speed: 1.2ms preprocess, 164.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(277, 110, 336, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(387, 112, 539, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.72, 좌표=(50, 151, 160, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.71, 좌표=(335, 117, 429, 280)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(553, 247, 614, 327)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.59, 좌표=(128, 127, 209, 284)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(334, 115, 428, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(217, 92, 297, 287)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.55, 좌표=(127, 126, 208, 357)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.55, 좌표=(214, 90, 300, 359)
#
# 0: 384x640 15 persons, 1 train, 2 handbags, 105.4ms
# Speed: 1.3ms preprocess, 105.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.79, 좌표=(276, 111, 337, 284)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.78, 좌표=(337, 116, 430, 280)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(389, 112, 538, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.69, 좌표=(47, 151, 160, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.64, 좌표=(129, 127, 210, 284)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(553, 247, 614, 327)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.59, 좌표=(336, 114, 430, 360)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(211, 95, 298, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(215, 94, 295, 288)
#
# 0: 384x640 17 persons, 1 train, 2 handbags, 103.9ms
# Speed: 1.4ms preprocess, 103.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.82, 좌표=(389, 112, 532, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.80, 좌표=(278, 113, 337, 284)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.78, 좌표=(340, 114, 431, 281)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.72, 좌표=(44, 151, 156, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(556, 247, 614, 327)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.58, 좌표=(127, 127, 206, 358)
#
# 0: 384x640 16 persons, 1 train, 2 handbags, 165.0ms
# Speed: 1.2ms preprocess, 165.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.79, 좌표=(278, 115, 337, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.79, 좌표=(390, 112, 529, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.74, 좌표=(342, 114, 433, 282)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.65, 좌표=(557, 247, 614, 326)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.64, 좌표=(43, 153, 154, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.64, 좌표=(207, 91, 295, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.60, 좌표=(126, 128, 207, 360)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(0, 226, 40, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.50, 좌표=(211, 93, 293, 288)
#
# 0: 384x640 15 persons, 1 train, 1 handbag, 110.2ms
# Speed: 1.5ms preprocess, 110.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.81, 좌표=(391, 112, 523, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(345, 110, 435, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.75, 좌표=(279, 117, 339, 284)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.69, 좌표=(43, 155, 153, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(206, 93, 295, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(126, 128, 206, 360)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.60, 좌표=(555, 247, 613, 327)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(333, 113, 374, 278)
#
# 0: 384x640 15 persons, 1 train, 1 handbag, 107.8ms
# Speed: 1.2ms preprocess, 107.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(347, 116, 438, 282)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.74, 좌표=(278, 118, 338, 283)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.71, 좌표=(37, 155, 155, 358)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(391, 112, 514, 282)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(127, 129, 206, 359)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.62, 좌표=(554, 247, 613, 327)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(332, 114, 374, 280)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.60, 좌표=(205, 93, 294, 359)
#
# 0: 384x640 1 person, 1 tv, 161.6ms
# Speed: 1.5ms preprocess, 161.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 116.2ms
# Speed: 1.4ms preprocess, 116.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 169.3ms
# Speed: 1.2ms preprocess, 169.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.5ms
# Speed: 1.1ms preprocess, 115.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 170.1ms
# Speed: 1.1ms preprocess, 170.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.52, 좌표=(553, 248, 613, 326)
#
# 0: 384x640 1 person, 1 tv, 115.2ms
# Speed: 1.0ms preprocess, 115.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(554, 248, 613, 327)
#
# 0: 384x640 1 person, 171.2ms
# Speed: 1.0ms preprocess, 171.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 114.9ms
# Speed: 1.2ms preprocess, 114.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(554, 246, 614, 328)
#
# 0: 384x640 1 person, 1 tv, 169.6ms
# Speed: 1.0ms preprocess, 169.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.57, 좌표=(554, 246, 614, 332)
#
# 0: 384x640 1 person, 115.2ms
# Speed: 1.0ms preprocess, 115.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 폰트 로드 오류: cannot open resource. 기본 폰트 사용
# 감지: 클래스=person, 신뢰도=0.56, 좌표=
ms preprocess, 112.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 처리된 비디오가 /content/output_video.mp4에 저장되었습니다.
# 처리된 비디오 다운로드 중...

# %%
# 필요한 라이브러리 설치
# yt-dlp: YouTube 비디오 다운로드
# ultralytics: YOLOv5 모델 사용
# opencv-python: 비디오 처리
# torch: 딥러닝 프레임워크
# !pip install yt-dlp ultralytics opencv-python torch

import cv2
import numpy as np
import yt_dlp
import torch
from ultralytics import YOLO
import os
from google.colab import files

# YouTube 비디오 다운로드 함수
def download_youtube_video(url, output_path):
    """
    주어진 YouTube URL에서 비디오를 다운로드하여 지정된 경로에 저장합니다.
    yt-dlp를 사용하여 안정적으로 다운로드합니다.

    Args:
        url (str): YouTube 비디오 URL
        output_path (str): 다운로드된 비디오를 저장할 경로
    Returns:
        str: 다운로드된 비디오 파일의 경로
    """
    try:
        # yt-dlp 옵션 설정
        ydl_opts = {
            'format': 'best[ext=mp4]',  # MP4 형식의 최고 품질 비디오 선택
            'outtmpl': os.path.join(output_path, 'input_video.mp4'),  # 출력 파일명
            'quiet': False,  # 진행 상황 출력
            'no_warnings': True,  # 경고 메시지 억제
        }

        print(f"비디오 다운로드 중: {url}")
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info = ydl.extract_info(url, download=True)
            print(f"다운로드 완료: {info['title']}")
        return os.path.join(output_path, 'input_video.mp4')
    except Exception as e:
        print(f"비디오 다운로드 오류: {str(e)}")
        return None

# 비디오 처리 및 사람 감지 함수
def process_video(video_path, output_path, model):
    """
    비디오를 처리하여 사람을 감지하고, 결과를 저장합니다.

    Args:
        video_path (str): 입력 비디오 경로
        output_path (str): 출력 비디오 저장 경로
        model: 사람 감지를 위한 사전 학습된 모델 (YOLOv5)
    """
    # 비디오 열기
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("오류: 비디오를 열 수 없습니다.")
        return

    # 비디오 속성 가져오기
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    # 출력 비디오 설정 (코덱 및 파일 생성)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # 프레임을 RGB로 변환 (YOLOv5는 RGB 입력을 요구)
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # 사람 감지 수행
        results = model(frame_rgb)

        # 감지 결과 처리
        if results and results[0].boxes:
            for detection in results[0].boxes.data:  # [x1, y1, x2, y2, 신뢰도, 클래스]
                class_id = int(detection[5])
                if class_id == 0:  # YOLOv5에서 클래스 0은 'person'
                    x1, y1, x2, y2 = map(int, detection[:4])
                    confidence = float(detection[4])
                    if confidence > 0.5:  # 신뢰도 임계값
                        # 바운딩 박스 그리기
                        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                        # 영어 라벨 추가
                        label = f"Person {confidence:.2f}"
                        cv2.putText(frame, label, (x1, y1-10),
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
                        # 디버깅용 출력
                        print(f"감지: 클래스={model.names[class_id]}, 신뢰도={confidence:.2f}, 좌표=({x1}, {y1}, {x2}, {y2})")

        # 처리된 프레임을 출력 비디오에 저장
        out.write(frame)

    # 자원 해제
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"처리된 비디오가 {output_path}에 저장되었습니다.")

# 메인 실행 함수
def main():
    # 경로 설정
    video_url = "https://youtu.be/uLC9ZpIavhI?si=FZijyhzvEeavjDt_"
    output_dir = "/content"
    output_video_path = "/content/output_video.mp4"

    # 출력 디렉토리 생성
    os.makedirs(output_dir, exist_ok=True)

    # YouTube 비디오 다운로드
    video_path = download_youtube_video(video_url, output_dir)

    # 비디오 다운로드 성공 여부 확인 후 처리 진행
    if video_path and os.path.exists(video_path):
        # YOLOv5 모델 로드 (Colab에서 빠른 추론을 위해 'yolov5s' 사용)
        print("YOLOv5 모델 로드 중...")
        model = YOLO('yolov5s.pt')  # 사전 학습된 YOLOv5 소형 모델

        # 클래스 이름 확인 (디버깅용)
        print(f"모델 클래스 이름: {model.names}")

        # 비디오 처리
        print("사람 감지를 위해 비디오 처리 중...")
        process_video(video_path, output_video_path, model)

        # 처리된 비디오 다운로드 (파일이 존재하는 경우에만 시도)
        if os.path.exists(output_video_path):
            print("처리된 비디오 다운로드 중...")
            files.download(output_video_path)
        else:
            print("오류: 처리된 비디오 파일을 찾을 수 없어 다운로드할 수 없습니다.")
    else:
        print("YouTube 비디오 다운로드에 실패하여 처리를 진행할 수 없습니다.")

if __name__ == "__main__":
    main()
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2025.7.21-py3-none-any.whl.metadata (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 3.0 MB/s eta 0:00:00
# Collecting ultralytics
#   Downloading ultralytics-8.3.170-py3-none-any.whl.metadata (37 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cpu)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.16.0)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cpu)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.7.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.7.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Downloading yt_dlp-2025.7.21-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 52.9 MB/s eta 0:00:00
# Downloading ultralytics-8.3.170-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.5 MB/s eta 0:00:00
# Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 17.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, yt-dlp, opencv-python, ultralytics-thop, ultralytics
# Successfully installed opencv-python-4.12.0.88 py-cpuinfo-9.0.0 ultralytics-8.3.170 ultralytics-thop-2.0.14 yt-dlp-2025.7.21
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 비디오 다운로드 중: https://youtu.be/uLC9ZpIavhI?si=FZijyhzvEeavjDt_
# [youtube] Extracting URL: https://youtu.be/uLC9ZpIavhI?si=FZijyhzvEeavjDt_
# [youtube] uLC9ZpIavhI: Downloading webpage
# [youtube] uLC9ZpIavhI: Downloading tv client config
# [youtube] uLC9ZpIavhI: Downloading player 662eb823-main
# [youtube] uLC9ZpIavhI: Downloading tv player API JSON
# [youtube] uLC9ZpIavhI: Downloading ios player API JSON
# [youtube] uLC9ZpIavhI: Downloading m3u8 information
# [info] uLC9ZpIavhI: Downloading 1 format(s): 18
# [download] Destination: /content/input_video.mp4
# [download] 100% of   16.67MiB in 00:00:01 at 15.86MiB/s
# 다운로드 완료: 언제나 주만 Always You, Jesus | 제이어스 J-US | Live Worship [Born Again]
# YOLOv5 모델 로드 중...
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov5su.pt to 'yolov5su.pt'...
# 100%|██████████| 17.7M/17.7M [00:00<00:00, 140MB/s]
# 모델 클래스 이름: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# 사람 감지를 위해 비디오 처리 중...
#
# 0: 384x640 (no detections), 133.9ms
# Speed: 2.9ms preprocess, 133.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 112.1ms
# Speed: 1.2ms preprocess, 112.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 108.4ms
# Speed: 1.3ms preprocess, 108.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.0ms
# Speed: 1.2ms preprocess, 162.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 112.4ms
# Speed: 1.2ms preprocess, 112.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 110.3ms
# Speed: 1.2ms preprocess, 110.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.5ms
# Speed: 1.3ms preprocess, 162.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 109.4ms
# Speed: 1.1ms preprocess, 109.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 115.4ms
# Speed: 1.1ms preprocess, 115.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 109.7ms
# Speed: 52.3ms preprocess, 109.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 110.6ms
# Speed: 1.0ms preprocess, 110.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 109

# 감지: 클래스=person, 신뢰도=0.61, 좌표=(192, 186, 230, 241)
#
# 0: 384x640 7 persons, 1 traffic light, 111.1ms
# Speed: 1.1ms preprocess, 111.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.62, 좌표=(365, 145, 392, 213)
#
# 0: 384x640 7 persons, 1 traffic light, 110.9ms
# Speed: 1.1ms preprocess, 110.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(364, 144, 391, 214)
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(181, 185, 218, 242)
#
# 0: 384x640 6 persons, 110.0ms
# Speed: 51.4ms preprocess, 110.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.59, 좌표=(364, 144, 391, 214)
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(177, 186, 217, 245)
#
# 0: 384x640 9 persons, 110.8ms
# Speed: 1.1ms preprocess, 110.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.66, 좌표=(174, 185, 215, 247)
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(364, 143, 394, 214)
# 감지: 클래스=person, 신뢰도=0.50, 좌표=(393, 186, 432, 229)
#
# 0: 384x640 8 persons, 110.8ms
# Speed: 1.1ms preprocess, 110.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.65, 좌표=(174, 185, 215, 247)
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(364, 143, 394, 214)
#
# 0: 384x640 10 persons, 108.3ms
# Speed: 1.2ms preprocess, 108.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.72, 좌표=(173, 185, 212, 251)
# 감지: 클래스=person, 신뢰도=0.62, 좌표=(365, 142, 396, 215)
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(394, 187, 433, 227)
#
# 0: 384x640 9 persons, 1 traffic light, 108.8ms
# Speed: 1.1ms preprocess, 108.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.66, 좌표=(167, 184, 208, 249)
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(366, 141, 395, 216)
# 감지: 클래스=person, 신뢰도=0.60, 좌표=(394, 187, 435, 224)
# 감지: 클래스=person, 신뢰도=0.55, 좌표=(285, 132, 318, 218)
#
# 0: 384x640 10 persons, 109.7ms
# Speed: 1.0ms preprocess, 109.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(165, 184, 206, 255)
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(365, 140, 395, 216)
# 감지: 클래스=person, 신뢰도=0.57, 좌표=(396, 187, 437, 224)
#
# 0: 384x640 8 persons, 1 car, 1 traffic light, 114.0ms
# Speed: 1.1ms preprocess, 114.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.69, 좌표=(397, 188, 439, 227)
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(447, 200, 491, 298)
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(161, 186, 203, 255)
# 감지: 클래스=person, 신뢰도=0.60, 좌표=(366, 139, 396, 216)
#
# 0: 384x640 11 persons, 1 traffic light, 111.7ms
# Speed: 1.1ms preprocess, 111.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.69, 좌표=(397, 188, 439, 227)
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(447, 200, 491, 298)
# 감지: 클래스=person, 신뢰도=0.62, 좌표=(161, 186, 203, 255)
# 감지: 클래스=person, 신뢰도=0.62, 좌표=(366, 140, 396, 216)
#
# 0: 384x640 12 persons, 162.5ms
# Speed: 1.1ms preprocess, 162.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(368, 139, 397, 216)
# 감지: 클래스=person, 신뢰도=0.68, 좌표=(398, 188, 440, 226)
# 감지: 클래스=person, 신뢰도=0.67, 좌표=(159, 185, 201, 259)
# 감지: 클래스=person, 신뢰도=0.50, 좌표=(447, 201, 492, 299)
#
# 0: 384x640 11 persons, 110.8ms
# Speed: 1.2ms preprocess, 110.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(369, 142, 399, 217)
# 감지: 클래스=person, 신뢰도=0.52, 좌표=(117, 181, 152, 270)
# 감지: 클래스=person, 신뢰도=0.52, 좌표=(562, 187, 591, 239)
#
# 0: 384x640 11 persons, 165.0ms
# Speed: 1.2ms preprocess, 165.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(370, 150, 401, 216)
# 감지: 클래스=person, 신뢰도=0.55, 좌표=(281, 129, 315, 226)
#
# 0: 384x640 13 persons, 114.4ms
# Speed: 1.0ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(371, 146, 402, 216)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(406, 189, 450, 237)
#
# 0: 384x640 14 persons, 109.7ms
# Speed: 1.1ms preprocess, 109.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(371, 146, 402, 216)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(406, 189, 450, 237)
#
# 0: 384x640 11 persons, 113.0ms
# Speed: 54.1ms preprocess, 113.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.72, 좌표=(371, 138, 403, 218)
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(277, 128, 312, 225)
# 감지: 클래스=person, 신뢰도=0.58, 좌표=(107, 182, 144, 278)
# 감지: 클래스=person, 신뢰도=0.55, 좌표=(406, 189, 449, 238)
#
# 0: 384x640 13 persons, 111.0ms
# Speed: 1.1ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(367, 135, 399, 218)
# 감지: 클래스=person, 신뢰도=0.58, 좌표=(94, 184, 132, 279)
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(129, 189, 181, 286)
#
# 0: 384x640 16 persons, 163.2ms
# Speed: 1.1ms preprocess, 163.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.68, 좌표=(365, 134, 401, 219)
# 감지: 클래스=person, 신뢰도=0.64, 좌표=(309, 216, 368, 340)
# 감지: 클래스=person, 신뢰도=0.57, 좌표=(87, 182, 127, 276)
# 감지: 클래스=person, 신뢰도=0.52, 좌표=(581, 189, 612, 244)
#
# 0: 384x640 13 persons, 115.2ms
# Speed: 1.2ms preprocess, 115.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.64, 좌표=(305, 216, 368, 342)
# 감지: 클래스=person, 신뢰도=0.62, 좌표=(119, 192, 168, 279)
# 감지: 클래스=person, 신뢰도=0.62, 좌표=(364, 133, 396, 219)
# 감지: 클래스=person, 신뢰도=0.58, 좌표=(75, 182, 121, 268)
#
# 0: 384x640 12 persons, 166.9ms
# Speed: 1.1ms preprocess, 166.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.67, 좌표=(305, 216, 368, 342)
# 감지: 클래스=person, 신뢰도=0.62, 좌표=(119, 192, 168, 280)
# 감지: 클래스=person, 신뢰도=0.62, 좌표=(364, 133, 396, 219)
# 감지: 클래스=person, 신뢰도=0.58, 좌표=(75, 182, 121, 268)
#
# 0: 384x640 12 persons, 109.3ms
# Speed: 1.1ms preprocess, 109.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(360, 133, 393, 219)
# 감지: 클래스=person, 신뢰도=0.69, 좌표=(112, 193, 163, 290)
# 감지: 클래스=person, 신뢰도=0.60, 좌표=(260, 125, 295, 229)
# 감지: 클래스=person, 신뢰도=0.59, 좌표=(70, 183, 115, 277)
#
# 0: 384x640 12 persons, 109.4ms
# Speed: 1.2ms preprocess, 109.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.66, 좌표=(352, 134, 384, 222)
# 감지: 클래스=person, 신뢰도=0.62, 좌표=(55, 183, 108, 269)
# 감지: 클래스=person, 신뢰도=0.57, 좌표=(105, 193, 152, 294)
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(557, 206, 595, 286)
#
# 0: 384x640 11 persons, 162.4ms
# Speed: 1.1ms preprocess, 162.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.79, 좌표=(95, 194, 146, 295)
# 감지: 클래스=person, 신뢰도=0.67, 좌표=(347, 134, 381, 223)
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(46, 184, 95, 268)
#
# 0: 384x640 11 persons, 112.6ms
# Speed: 1.2ms preprocess, 112.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(90, 194, 140, 297)
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(39, 184, 86, 269)
# 감지: 클래스=person, 신뢰도=0.69, 좌표=(343, 133, 377, 224)
#
# 0: 384x640 13 persons, 111.2ms
# Speed: 1.2ms preprocess, 111.2ms inference, 54.1ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(39, 184, 86, 269)
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(90, 194, 140, 297)
# 감지: 클래스=person, 신뢰도=0.69, 좌표=(343, 133, 377, 224)
#
# 0: 384x640 10 persons, 113.5ms
# Speed: 1.1ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.71, 좌표=(338, 133, 372, 224)
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(85, 194, 133, 296)
# 감지: 클래스=person, 신뢰도=0.60, 좌표=(32, 185, 79, 269)
#
# 0: 384x640 14 persons, 113.3ms
# Speed: 1.2ms preprocess, 113.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.65, 좌표=(18, 185, 66, 269)
# 감지: 클래스=person, 신뢰도=0.60, 좌표=(326, 134, 360, 225)
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(219, 124, 256, 228)
#
# 0: 384x640 11 persons, 111.9ms
# Speed: 51.2ms preprocess, 111.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.70, 좌표=(321, 133, 355, 225)
# 감지: 클래스=person, 신뢰도=0.67, 좌표=(64, 194, 116, 274)
# 감지: 클래스=person, 신뢰도=0.62, 좌표=(7, 185, 60, 272)
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(211, 123, 250, 227)
#
# 0: 384x640 14 persons, 111.5ms
# Speed: 1.1ms preprocess, 111.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.74, 좌표=(317, 132, 353, 223)
# 감지: 클래스=person, 신뢰도=0.67, 좌표=(203, 122, 246, 227)
# 감지: 클래스=person, 신뢰도=0.57, 좌표=(58, 195, 114, 305)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(2, 185, 58, 270)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(254, 212, 299, 276)
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(352, 191, 398, 237)
#
# 0: 384x640 14 persons, 167.7ms
# Speed: 1.1ms preprocess, 167.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.74, 좌표=(317, 132, 353, 223)
# 감지: 클래스=person, 신뢰도=0.67, 좌표=(203, 122, 246, 227)
# 감지: 클래스=person, 신뢰도=0.57, 좌표=(58, 195, 114, 305)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(2, 185, 58, 270)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(254, 212, 299, 276)
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(352, 191, 398, 237)
#
# 0: 384x640 9 persons, 115.3ms
# Speed: 1.0ms preprocess, 115.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(199, 121, 243, 229)
# 감지: 클래스=person, 신뢰도=0.73, 좌표=(316, 131, 351, 221)
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(55, 192, 113, 296)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(7, 185, 55, 271)
#
# 0: 384x640 10 persons, 163.5ms
# Speed: 1.0ms preprocess, 163.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.71, 좌표=(315, 129, 350, 217)
# 감지: 클래스=person, 신뢰도=0.65, 좌표=(195, 120, 240, 229)
# 감지: 클래스=person, 신뢰도=0.51, 좌표=(250, 213, 294, 274)
#
# 0: 384x640 12 persons, 108.9ms
# Speed: 1.1ms preprocess, 108.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.75, 좌표=(314, 130, 349, 218)
# 감지: 클래스=person, 신뢰도=0.64, 좌표=(193, 120, 237, 229)
#
# 0: 384x640 11 persons, 110.4ms
# Speed: 1.0ms preprocess, 110.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.72, 좌표=(314, 129, 349, 216)
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(192, 119, 236, 229)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(0, 185, 51, 309)
# 감지: 클래스=person, 신뢰도=0.52, 좌표=(249, 213, 292, 271)
#
# 0: 384x640 11 persons, 1 traffic light, 163.1ms
# Speed: 1.0ms preprocess, 163.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.72, 좌표=(314, 129, 349, 216)
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(192, 119, 236, 229)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(0, 185, 51, 309)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(249, 213, 292, 271)
#
# 0: 384x640 10 persons, 113.1ms
# Speed: 1.1ms preprocess, 113.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.66, 좌표=(314, 130, 348, 216)
# 감지: 클래스=person, 신뢰도=0.57, 좌표=(192, 119, 235, 231)
# 감지: 클래스=person, 신뢰도=0.55, 좌표=(0, 185, 46, 307)
# 감지: 클래스=person, 신뢰도=0.54, 좌표=(544, 185, 587, 248)
#
# 0: 384x640 9 persons, 166.3ms
# Speed: 1.0ms preprocess, 166.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.67, 좌표=(316, 130, 350, 217)
# 감지: 클래스=person, 신뢰도=0.66, 좌표=(0, 184, 44, 310)
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(193, 120, 237, 227)
#
# 0: 384x640 7 persons, 111.3ms
# Speed: 1.2ms preprocess, 111.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(320, 131, 354, 213)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(197, 119, 240, 227)
# 감지: 클래스=person, 신뢰도=0.50, 좌표=(8, 184, 46, 290)
#
# 0: 384x640 10 persons, 108.2ms
# Speed: 1.1ms preprocess, 108.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.55, 좌표=(4, 184, 50, 315)
# 감지: 클래스=person, 신뢰도=0.54, 좌표=(324, 132, 359, 212)
#
# 0: 384x640 10 persons, 163.8ms
# Speed: 1.0ms preprocess, 163.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(4, 184, 50, 314)
# 감지: 클래스=person, 신뢰도=0.54, 좌표=(324, 132, 359, 212)
#
# 0: 384x640 4 persons, 110.0ms
# Speed: 1.1ms preprocess, 110.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 108.5ms
# Speed: 1.1ms preprocess, 108.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.58, 좌표=(41, 184, 79, 304)
#
# 0: 384x640 5 persons, 111.9ms
# Speed: 1.1ms preprocess, 111.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 112.7ms
# Speed: 1.1ms preprocess, 112.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.52, 좌표=(66, 183, 102, 292)
#
# 0: 384x640 5 persons, 165.8ms
# Speed: 1.2ms preprocess, 165.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.52, 좌표=(66, 183, 102, 292)
#
# 0: 384x640 7 persons, 109.9ms
# Speed: 1.1ms preprocess, 109.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.58, 좌표=(273, 234, 324, 309)
#
# 0: 384x640 9 persons, 109.9ms
# Speed: 1.1ms preprocess, 109.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.64, 좌표=(525, 234, 600, 355)
#
# 0: 384x640 8 persons, 110.3ms
# Speed: 51.7ms preprocess, 110.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 110.1ms
# Speed: 1.1ms preprocess, 110.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(415, 130, 448, 219)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(225, 270, 308, 358)
# 감지: 클래스=person, 신뢰도=0.52, 좌표=(110, 184, 153, 309)
#
# 0: 384x640 10 persons, 165.1ms
# Speed: 1.1ms preprocess, 165.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.56, 좌표=(415, 130, 448, 219)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(225, 269, 308, 358)
# 감지: 클래스=person, 신뢰도=0.52, 좌표=(110, 184, 153, 309)
#
# 0: 384x640 2 persons, 1 tie, 116.6ms
# Speed: 1.1ms preprocess, 116.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.84, 좌표=(197, 34, 358, 355)
# 감지: 클래스=person, 신뢰도=0.81, 좌표=(18, 185, 225, 356)
#
# 0: 384x640 2 persons, 1 tie, 166.8ms
# Speed: 1.1ms preprocess, 166.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.83, 좌표=(199, 33, 363, 349)
# 감지: 클래스=person, 신뢰도=0.77, 좌표=(14, 187, 222, 356)
#
# 0: 384x640 3 persons, 108.2ms
# Speed: 1.0ms preprocess, 108.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.83, 좌표=(17, 190, 219, 357)
#
# 0: 384x640 2 persons, 1 tie, 1 cell phone, 112.0ms
# Speed: 1.0ms preprocess, 112.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.78, 좌표=(24, 193, 217, 357)
# 감지: 클래스=person, 신뢰도=0.78, 좌표=(207, 42, 364, 347)
#
# 0: 384x640 2 persons, 1 tie, 1 cell phone, 163.7ms
# Speed: 1.1ms preprocess, 163.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.78, 좌표=(24, 193, 217, 357)
# 감지: 클래스=person, 신뢰도=0.77, 좌표=(207, 42, 364, 347)
#
# 0: 384x640 2 persons, 110.6ms
# Speed: 1.1ms preprocess, 110.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.78, 좌표=(20, 195, 217, 356)
#
# ...
# Speed: 1.1ms preprocess, 112.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.89, 좌표=(241, 51, 415, 282)
# 감지: 클래스=person, 신뢰도=0.80, 좌표=
3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.86, 좌표=(244, 48, 416, 282)
# 감지: 클래스=person, 신뢰도=0.76, 좌표=(510, 144, 569, 246)
# 감지: 클래스=person, 신뢰도=0.68, 좌표=(381, 138, 437, 222)
#
# 0: 384x640 3 persons, 1 tv, 1 remote, 1 keyboard, 110.8ms
# Speed: 1.1ms preprocess, 110.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.87, 좌표=(244, 49, 416, 281)
# 감지: 클래스=person, 신뢰도=0.78, 좌표=(381, 138, 437, 222)
# 감지: 클래스=person, 신뢰도=0.75, 좌표=(510, 144, 570, 246)
#
# 0: 384x640 2 persons, 166.5ms
# Speed: 1.1ms preprocess, 166.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.91, 좌표=(230, 26, 561, 357)
# 감지: 클래스=person, 신뢰도=0.68, 좌표=(574, 202, 639, 357)
#
# 0: 384x640 2 persons, 115.7ms
# Speed: 1.1ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.89, 좌표=(234, 25, 547, 358)
# 감지: 클래스=person, 신뢰도=0.65, 좌표=(574, 201, 639, 357)
#
# 0: 384x640 2 persons, 167.1ms
# Speed: 1.0ms preprocess, 167.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.89, 좌표=(234, 25, 547, 358)
# 감지: 클래스=person, 신뢰도=0.65, 좌표=(574, 201, 639, 357)
#
# 0: 384x640 2 persons, 111.3ms
# Speed: 1.1ms preprocess, 111.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.89, 좌표=(237, 26, 529, 358)
# 감지: 클래스=person, 신뢰도=0.63, 좌표=(574, 201, 639, 357)
#
# 0: 384x640 2 persons, 166.9ms
# Speed: 1.1ms preprocess, 166.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.88, 좌표=(240, 29, 513, 354)
# 감지: 클래스=person, 신뢰도=0.58, 좌표=(574, 201, 639, 357)
#
# 0: 384x640 2 persons, 110.0ms
# Speed: 1.1ms preprocess, 110.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.91, 좌표=(243, 31, 506, 356)
# 감지: 클래스=person, 신뢰도=0.68, 좌표=(572, 201, 639, 357)
#
# 0: 384x640 2 persons, 112.1ms
# Speed: 1.2ms preprocess, 112.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.92, 좌표=(244, 34, 504, 356)
# 감지: 클래스=person, 신뢰도=0.62, 좌표=(573, 201, 639, 356)
#
# 0: 384x640 2 persons, 114.7ms
# Speed: 52.7ms preprocess, 114.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.92, 좌표=(244, 34, 504, 356)
# 감지: 클래스=person, 신뢰도=0.61, 좌표=(573, 201, 639, 356)
#
# 0: 384x640 2 persons, 115.4ms
# Speed: 1.1ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.92, 좌표=(244, 34, 506, 356)
# 감지: 클래스=person, 신뢰도=0.67, 좌표=(573, 200, 639, 357)
#
# 0: 384x640 2 persons, 165.9ms
# Speed: 1.1ms preprocess, 165.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.92, 좌표=(244, 30, 511, 357)
# 감지: 클래스=person, 신뢰도=0.52, 좌표=(574, 201, 639, 358)
#
# 0: 384x640 2 persons, 110.2ms
# Speed: 1.2ms preprocess, 110.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.92, 좌표=(246, 30, 515, 357)
# 감지: 클래스=person, 신뢰도=0.59, 좌표=(573, 203, 639, 358)
#
# 0: 384x640 2 persons, 1 toothbrush, 166.5ms
# Speed: 1.1ms preprocess, 166.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.93, 좌표=(247, 30, 514, 357)
# 감지: 클래스=person, 신뢰도=0.59, 좌표=(572, 197, 639, 357)
#
# 0: 384x640 2 persons, 1 toothbrush, 111.8ms
# Speed: 1.1ms preprocess, 111.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.92, 좌표=(247, 29, 514, 357)
# 감지: 클래스=person, 신뢰도=0.59, 좌표=(572, 197, 639, 357)
#
# 0: 384x640 2 persons, 112.4ms
# Speed: 1.1ms preprocess, 112.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.92, 좌표=(248, 30, 513, 357)
#
# 0: 384x640 2 persons, 110.4ms
# Speed: 52.2ms preprocess, 110.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.91, 좌표=(248, 31, 509, 357)
#
# 0: 384x640 2 persons, 112.7ms
# Speed: 1.1ms preprocess, 112.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.86, 좌표=(252, 32, 508, 357)
#
# 0: 384x640 2 persons, 165.2ms
# Speed: 1.1ms preprocess, 165.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.86, 좌표=(253, 33, 507, 358)
#
# 0: 384x640 2 persons, 111.0ms
# Speed: 1.1ms preprocess, 111.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.86, 좌표=(253, 33, 508, 357)
#
# 0: 384x640 1 person, 112.4ms
# Speed: 1.1ms preprocess, 112.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.90, 좌표=(254, 32, 505, 357)
#
# 0: 384x640 2 persons, 110.4ms
# Speed: 53.4ms preprocess, 110.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.91, 좌표=(254, 31, 507, 357)
#
# 0: 384x640 2 persons, 110.8ms
# Speed: 1.1ms preprocess, 110.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.90, 좌표=(255, 31, 508, 357)
#
# 0: 384x640 2 persons, 163.9ms
# Speed: 1.1ms preprocess, 163.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.90, 좌표=(254, 29, 508, 358)
# 감지: 클래스=person, 신뢰도=0.54, 좌표=(572, 196, 639, 356)
#
# 0: 384x640 2 persons, 112.1ms
# Speed: 1.2ms preprocess, 112.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.90, 좌표=(254, 29, 508, 358)
# 감지: 클래스=person, 신뢰도=0.53, 좌표=(572, 196, 639, 356)
#
# 0: 384x640 2 persons, 109.2ms
# Speed: 1.1ms preprocess, 109.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.89, 좌표=(255, 28, 507, 357)
#
# 0: 384x640 2 persons, 163.8ms
# Speed: 1.1ms preprocess, 163.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.88, 좌표=(255, 27, 508, 358)
#
# 0: 384x640 2 persons, 109.2ms
# Speed: 1.1ms preprocess, 109.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.87, 좌표=(254, 28, 504, 357)
#
# 0: 384x640 2 persons, 108.8ms
# Speed: 1.1ms preprocess, 108.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.88, 좌표=(254, 28, 503, 357)
#
# 0: 384x640 2 persons, 161.8ms
# Speed: 1.0ms preprocess, 161.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.88, 좌표=(254, 28, 503, 357)
#
# 0: 384x640 1 person, 113.7ms
# Speed: 1.1ms preprocess, 113.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.89, 좌표=(254, 29, 502, 357)
#
# 0: 384x640 2 persons, 109.9ms
# Speed: 1.1ms preprocess, 109.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.89, 좌표=(255, 30, 500, 357)
#
# 0: 384x640 2 persons, 111.0ms
# Speed: 1.3ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.88, 좌표=(255, 32, 500, 357)
#
# 0: 384x640 2 persons, 114.6ms
# Speed: 1.1ms preprocess, 114.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.88, 좌표=(255, 32, 500, 357)
#
# 0: 384x640 2 persons, 167.0ms
# Speed: 1.0ms preprocess, 167.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.88, 좌표=(255, 32, 500, 357)
#
# 0: 384x640 2 persons, 111.4ms
# Speed: 1.1ms preprocess, 111.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.86, 좌표=(255, 31, 501, 357)
#
# 0: 384x640 2 persons, 108.4ms
# Speed: 1.1ms preprocess, 108.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.83, 좌표=(255, 29, 501, 356)
#
# 0: 384x640 2 persons, 112.6ms
# Speed: 1.1ms preprocess, 112.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.87, 좌표=(255, 26, 503, 356)
#
# 0: 384x640 2 persons, 111.8ms
# Speed: 1.1ms preprocess, 111.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.87, 좌표=(257, 26, 504, 357)
#
# 0: 384x640 2 persons, 163.8ms
# Speed: 1.1ms preprocess, 163.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.87, 좌표=(257, 27, 504, 357)
#
# 0: 384x640 2 persons, 112.5ms
# Speed: 1.2ms preprocess, 112.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.88, 좌표=(258, 28, 505, 357)
#
# 0: 384x640 2 persons, 110.9ms
# Speed: 1.1ms preprocess, 110.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.89, 좌표=(258, 30, 506, 357)
#
# 0: 384x640 2 persons, 110.0ms
# Speed: 1.1ms preprocess, 110.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.89, 좌표=(258, 28, 504, 357)
#
# 0: 384x640 2 persons, 110.4ms
# Speed: 1.1ms preprocess, 110.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.89, 좌표=(258, 29, 505, 357)
#
# 0: 384x640 2 persons, 163.1ms
# Speed: 1.1ms preprocess, 163.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.89, 좌표=(258, 29, 505, 357)
#
# 0: 384x640 2 persons, 112.0ms
# Speed: 1.2ms preprocess, 112.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.90, 좌표=(259, 31, 506, 357)
#
# 0: 384x640 2 persons, 111.7ms
# Speed: 1.1ms preprocess, 111.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.91, 좌표=(259, 35, 508, 357)
#
# 0: 384x640 2 persons, 110.7ms
# Speed: 54.4ms preprocess, 110.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.90, 좌표=(260, 37, 510, 357)
#
# 0: 384x640 2 persons, 110.9ms
# Speed: 1.1ms preprocess, 110.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.90, 좌표=(260, 33, 511, 358)
#
# 0: 384x640 2 persons, 108.2ms
# Speed: 1.1ms preprocess, 108.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 감지: 클래스=person, 신뢰도=0.89, 좌표=(260, 33, 511, 358)

# %%
# 필요한 라이브러리 설치
# yt-dlp: YouTube 비디오 다운로드
# ultralytics: YOLOv5 모델 사용
# opencv-python: 비디오 처리
# torch: 딥러닝 프레임워크
# !pip install yt-dlp ultralytics opencv-python torch

import cv2
import numpy as np
import yt_dlp
import torch
from ultralytics import YOLO
import os
from google.colab import files

# YouTube 비디오 다운로드 함수
def download_youtube_video(url, output_path):
    """
    주어진 YouTube URL에서 비디오를 다운로드하여 지정된 경로에 저장합니다.
    yt-dlp를 사용하여 안정적으로 다운로드합니다.

    Args:
        url (str): YouTube 비디오 URL
        output_path (str): 다운로드된 비디오를 저장할 경로
    Returns:
        str: 다운로드된 비디오 파일의 경로
    """
    try:
        ydl_opts = {
            'format': 'best[ext=mp4]',  # MP4 형식의 최고 품질 비디오 선택
            'outtmpl': os.path.join(output_path, 'input_video.mp4'),  # 출력 파일명
            'quiet': False,  # 진행 상황 출력
            'no_warnings': True,  # 경고 메시지 억제
        }

        print(f"비디오 다운로드 중: {url}")
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info = ydl.extract_info(url, download=True)
            print(f"다운로드 완료: {info['title']}")
        return os.path.join(output_path, 'input_video.mp4')
    except Exception as e:
        print(f"비디오 다운로드 오류: {str(e)}")
        return None

# 비디오 처리 및 차량 감지 함수
def process_video(video_path, output_path, model):
    """
    비디오를 처리하여 차량을 감지하고, 결과를 저장합니다.
    YOLOv5를 사용하여 슈퍼카(예: car, truck, bus 등)를 감지.

    Args:
        video_path (str): 입력 비디오 경로
        output_path (str): 출력 비디오 저장 경로
        model: 차량 감지를 위한 사전 학습된 모델
    """
    # 비디오 열기
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("오류: 비디오를 열 수 없습니다.")
        return

    # 비디오 속성 가져오기
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    # 출력 비디오 설정 (코덱 및 파일 생성)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    frame_count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1
        if frame_count % 2 == 0:  # 프레임 속도 줄이기 (성능 최적화)
            continue

        # 프레임을 RGB로 변환 (YOLOv5는 RGB 입력을 요구)
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # 차량 감지 수행
        results = model(frame_rgb, conf=0.3)  # 신뢰도 임계값 0.3으로 설정

        # 감지 결과 처리
        if results and results[0].boxes:
            for detection in results[0].boxes.data:  # [x1, y1, x2, y2, 신뢰도, 클래스]
                class_id = int(detection[5])
                # YOLOv5 COCO 데이터셋에서 차량 관련 클래스
                vehicle_classes = [2, 5, 7]  # car: 2, bus: 5, truck: 7
                if class_id in vehicle_classes:
                    x1, y1, x2, y2 = map(int, detection[:4])
                    confidence = float(detection[4])
                    if confidence > 0.3:  # 낮춘 신뢰도 임계값 적용
                        # 바운딩 박스 그리기
                        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                        # 영어 라벨 추가
                        class_names = ["car", "bus", "truck"]  # vehicle_classes에 맞춘 순서
                        label = f"{class_names[vehicle_classes.index(class_id)]} {confidence:.2f}"
                        cv2.putText(frame, label, (x1, y1-10),
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
                        print(f"프레임 {frame_count}: 감지 - 클래스={class_names[vehicle_classes.index(class_id)]}, 신뢰도={confidence:.2f}, 좌표=({x1}, {y1}, {x2}, {y2})")

        # 처리된 프레임을 출력 비디오에 저장
        out.write(frame)

    # 자원 해제
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"처리된 비디오가 {output_path}에 저장되었습니다.")

# 메인 실행 함수
def main():
    # 경로 설정
    video_url = "https://youtu.be/b_P7qRD2czM?si=4VhT26mQHrLpC8Ik"
    output_dir = "/content"
    output_video_path = "/content/output_video.mp4"

    # 출력 디렉토리 생성
    os.makedirs(output_dir, exist_ok=True)

    # YouTube 비디오 다운로드
    video_path = download_youtube_video(video_url, output_dir)

    # 비디오 다운로드 성공 여부 확인 후 처리 진행
    if video_path and os.path.exists(video_path):
        # YOLOv5 모델 로드 (더 강력한 'yolov5m' 사용)
        print("YOLOv5 모델 로드 중...")
        model = YOLO('yolov5m.pt')  # yolv5m.pt로 업그레이드

        # 클래스 이름 확인 (디버깅용)
        print(f"모델 클래스 이름: {model.names}")

        # 비디오 처리
        print("차량 감지를 위해 비디오 처리 중...")
        process_video(video_path, output_video_path, model)

        # 처리된 비디오 다운로드 (파일이 존재하는 경우에만 시도)
        if os.path.exists(output_video_path):
            print("처리된 비디오 다운로드 중...")
            files.download(output_video_path)
        else:
            print("오류: 처리된 비디오 파일을 찾을 수 없어 다운로드할 수 없습니다.")
    else:
        print("YouTube 비디오 다운로드에 실패하여 처리를 진행할 수 없습니다.")

if __name__ == "__main__":
    main()
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2025.7.21-py3-none-any.whl.metadata (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 3.2 MB/s eta 0:00:00
# Collecting ultralytics
#   Downloading ultralytics-8.3.170-py3-none-any.whl.metadata (37 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cpu)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.16.0)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cpu)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.7.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.7.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Downloading yt_dlp-2025.7.21-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 39.1 MB/s eta 0:00:00
# Downloading ultralytics-8.3.170-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.4 MB/s eta 0:00:00
# Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 17.3 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, yt-dlp, opencv-python, ultralytics-thop, ultralytics
# Successfully installed opencv-python-4.12.0.88 py-cpuinfo-9.0.0 ultralytics-8.3.170 ultralytics-thop-2.0.14 yt-dlp-2025.7.21
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 비디오 다운로드 중: https://youtu.be/b_P7qRD2czM?si=4VhT26mQHrLpC8Ik
# [youtube] Extracting URL: https://youtu.be/b_P7qRD2czM?si=4VhT26mQHrLpC8Ik
# [youtube] b_P7qRD2czM: Downloading webpage
# [youtube] b_P7qRD2czM: Downloading tv client config
# [youtube] b_P7qRD2czM: Downloading player 662eb823-main
# [youtube] b_P7qRD2czM: Downloading tv player API JSON
# [youtube] b_P7qRD2czM: Downloading ios player API JSON
# [youtube] b_P7qRD2czM: Downloading m3u8 information
# [info] b_P7qRD2czM: Downloading 1 format(s): 18
# [download] Destination: /content/input_video.mp4
# [download] 100% of   11.25MiB in 00:00:03 at 3.29MiB/s
# 다운로드 완료: 직접 타본 5대 슈퍼카 주행 느낌 비교 (720S, 570S, 458, 우라칸 580, 우루스)
# YOLOv5 모델 로드 중...
# PRO TIP 💡 Replace 'model=yolov5m.pt' with new 'model=yolov5mu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov5mu.pt to 'yolov5mu.pt'...
# 100%|██████████| 48.2M/48.2M [00:00<00:00, 138MB/s]
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 프레임 3733: 감지 - 클래스=car, 신뢰도=0.43, 좌표=(1, 1, 635, 359)
#
# 0: 384x640 1 car, 271.4ms
# Speed: 1.1ms preprocess, 271.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3735: 감지 - 클래스=car, 신뢰도=0.46, 좌표=(1, 1, 635, 359)
#
# 0: 384x640 1 car, 218.1ms
# Speed: 1.2ms preprocess, 218.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3737: 감지 - 클래스=car, 신뢰도=0.38, 좌표=(1, 11, 631, 356)
#
# 0: 384x640 (no detections), 265.1ms
# Speed: 1.2ms preprocess, 265.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 211.7ms
# Speed: 1.1ms preprocess, 211.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 268.9ms
# Speed: 1.1ms preprocess, 268.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 219.6ms
# Speed: 1.3ms preprocess, 219.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 268.3ms
# Speed: 1.3ms preprocess, 268.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 213.7ms
# Speed: 1.3ms preprocess, 213.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 267.5ms
# Speed: 1.1ms preprocess, 267.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3751: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(2, 0, 626, 356)
#
# 0: 384x640 1 car, 216.4ms
# Speed: 1.3ms preprocess, 216.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3753: 감지 - 클래스=car, 신뢰도=0.46, 좌표=(2, 0, 626, 352)
#
# 0: 384x640 1 car, 266.0ms
# Speed: 1.2ms preprocess, 266.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3755: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(2, 1, 624, 355)
#
# 0: 384x640 1 car, 213.4ms
# Speed: 1.2ms preprocess, 213.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3757: 감지 - 클래스=car, 신뢰도=0.33, 좌표=(2, 0, 631, 354)
#
# 0: 384x640 1 car, 266.0ms
# Speed: 1.3ms preprocess, 266.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3759: 감지 - 클래스=car, 신뢰도=0.42, 좌표=(2, 0, 618, 354)
#
# 0: 384x640 1 car, 213.2ms
# Speed: 1.1ms preprocess, 213.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3761: 감지 - 클래스=car, 신뢰도=0.38, 좌표=(4, 0, 634, 356)
#
# 0: 384x640 1 car, 210.6ms
# Speed: 1.2ms preprocess, 210.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3763: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(3, 0, 627, 355)
#
# 0: 384x640 1 car, 214.7ms
# Speed: 52.1ms preprocess, 214.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3765: 감지 - 클래스=car, 신뢰도=0.41, 좌표=(2, 0, 634, 352)
#
# 0: 384x640 1 car, 214.4ms
# Speed: 1.2ms preprocess, 214.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3767: 감지 - 클래스=car, 신뢰도=0.42, 좌표=(3, 0, 633, 354)
#
# 0: 384x640 1 car, 271.6ms
# Speed: 1.2ms preprocess, 271.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3769: 감지 - 클래스=car, 신뢰도=0.47, 좌표=(1, 4, 630, 352)
#
# 0: 384x640 1 car, 214.3ms
# Speed: 1.3ms preprocess, 214.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3771: 감지 - 클래스=car, 신뢰도=0.40, 좌표=(2, 0, 635, 360)
#
# 0: 384x640 1 car, 214.2ms
# Speed: 54.0ms preprocess, 214.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3773: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(3, 2, 635, 357)
#
# 0: 384x640 (no detections), 214.4ms
# Speed: 1.1ms preprocess, 214.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 268.6ms
# Speed: 1.3ms preprocess, 268.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3777: 감지 - 클래스=car, 신뢰도=0.47, 좌표=(2, 3, 635, 354)
#
# 0: 384x640 1 car, 219.5ms
# Speed: 1.2ms preprocess, 219.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3779: 감지 - 클래스=car, 신뢰도=0.45, 좌표=(1, 5, 632, 353)
#
# 0: 384x640 1 car, 221.3ms
# Speed: 52.0ms preprocess, 221.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3781: 감지 - 클래스=car, 신뢰도=0.40, 좌표=(2, 8, 631, 359)
#
# 0: 384x640 (no detections), 215.3ms
# Speed: 1.2ms preprocess, 215.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 216.8ms
# Speed: 1.5ms preprocess, 216.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 278.6ms
# Speed: 1.2ms preprocess, 278.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 222.2ms
# Speed: 1.3ms preprocess, 222.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3789: 감지 - 클래스=car, 신뢰도=0.42, 좌표=(3, 2, 633, 354)
#
# 0: 384x640 1 car, 222.3ms
# Speed: 52.1ms preprocess, 222.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3791: 감지 - 클래스=car, 신뢰도=0.55, 좌표=(2, 0, 632, 360)
#
# 0: 384x640 1 car, 269.6ms
# Speed: 1.1ms preprocess, 269.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3793: 감지 - 클래스=car, 신뢰도=0.44, 좌표=(1, 0, 630, 353)
#
# 0: 384x640 1 car, 214.8ms
# Speed: 1.2ms preprocess, 214.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3795: 감지 - 클래스=car, 신뢰도=0.33, 좌표=(1, 1, 633, 357)
#
# 0: 384x640 (no detections), 270.7ms
# Speed: 1.1ms preprocess, 270.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 213.8ms
# Speed: 1.2ms preprocess, 213.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 213.2ms
# Speed: 1.1ms preprocess, 213.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 213.7ms
# Speed: 1.2ms preprocess, 213.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 212.2ms
# Speed: 1.2ms preprocess, 212.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3805: 감지 - 클래스=car, 신뢰도=0.32, 좌표=(1, 3, 636, 353)
#
# 0: 384x640 (no detections), 210.7ms
# Speed: 54.6ms preprocess, 210.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 212.8ms
# Speed: 1.1ms preprocess, 212.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 265.3ms
# Speed: 1.3ms preprocess, 265.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 213.3ms
# Speed: 1.2ms preprocess, 213.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 273.3ms
# Speed: 1.1ms preprocess, 273.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 217.7ms
# Speed: 1.1ms preprocess, 217.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 266.2ms
# Speed: 1.3ms preprocess, 266.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 214.5ms
# Speed: 1.2ms preprocess, 214.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 270.7ms
# Speed: 1.1ms preprocess, 270.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3823: 감지 - 클래스=car, 신뢰도=0.35, 좌표=(1, 0, 633, 351)
#
# 0: 384x640 (no detections), 216.0ms
# Speed: 1.1ms preprocess, 216.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 266.3ms
# Speed: 1.2ms preprocess, 266.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 214.7ms
# Speed: 1.1ms preprocess, 214.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 212.8ms
# Speed: 1.2ms preprocess, 212.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 215.1ms
# Speed: 1.5ms preprocess, 215.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 213.7ms
# Speed: 1.2ms preprocess, 213.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3835: 감지 - 클래스=car, 신뢰도=0.30, 좌표=(3, 9, 635, 358)
#
# 0: 384x640 (no detections), 214.4ms
# Speed: 52.0ms preprocess, 214.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 213.2ms
# Speed: 1.2ms preprocess, 213.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 268.4ms
# Speed: 1.1ms preprocess, 268.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 210.8ms
# Speed: 1.2ms preprocess, 210.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 267.8ms
# Speed: 1.2ms preprocess, 267.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 217.1ms
# Speed: 1.2ms preprocess, 217.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 268.5ms
# Speed: 1.3ms preprocess, 268.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 214.5ms
# Speed: 1.2ms preprocess, 214.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 269.4ms
# Speed: 1.2ms preprocess, 269.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 216.3ms
# Speed: 1.2ms preprocess, 216.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 265.4ms
# Speed: 1.1ms preprocess, 265.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 213.2ms
# Speed: 1.2ms preprocess, 213.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 217.1ms
# Speed: 1.2ms preprocess, 217.1ms inference, 51.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 211.1ms
# Speed: 1.2ms preprocess, 211.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 216.4ms
# Speed: 1.2ms preprocess, 216.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 213.8ms
# Speed: 53.1ms preprocess, 213.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 213.7ms
# Speed: 1.2ms preprocess, 213.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3869: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(1, 1, 632, 351)
#
# 0: 384x640 1 motorcycle, 263.0ms
# Speed: 1.1ms preprocess, 263.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 215.8ms
# Speed: 1.2ms preprocess, 215.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 277.4ms
# Speed: 1.3ms preprocess, 277.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 216.8ms
# Speed: 1.2ms preprocess, 216.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 211.4ms
# Speed: 55.5ms preprocess, 211.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 224.6ms
# Speed: 1.2ms preprocess, 224.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 221.3ms
# Speed: 1.2ms preprocess, 221.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 275.0ms
# Speed: 1.2ms preprocess, 275.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 218.9ms
# Speed: 1.3ms preprocess, 218.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 269.4ms
# Speed: 1.2ms preprocess, 269.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 215.9ms
# Speed: 1.4ms preprocess, 215.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 269.8ms
# Speed: 1.3ms preprocess, 269.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 214.8ms
# Speed: 1.3ms preprocess, 214.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 265.4ms
# Speed: 1.1ms preprocess, 265.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 214.5ms
# Speed: 1.2ms preprocess, 214.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 269.6ms
# Speed: 1.3ms preprocess, 269.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 213.9ms
# Speed: 1.2ms preprocess, 213.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3903: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(2, 1, 636, 358)
#
# 0: 384x640 1 car, 269.7ms
# Speed: 1.3ms preprocess, 269.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3905: 감지 - 클래스=car, 신뢰도=0.37, 좌표=(3, 3, 635, 355)
#
# 0: 384x640 (no detections), 212.9ms
# Speed: 1.3ms preprocess, 212.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 210.3ms
# Speed: 1.3ms preprocess, 210.3ms inference, 54.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 213.7ms
# Speed: 1.3ms preprocess, 213.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 214.0ms
# Speed: 1.2ms preprocess, 214.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 214.3ms
# Speed: 1.3ms preprocess, 214.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 212.9ms
# Speed: 1.4ms preprocess, 212.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 264.0ms
# Speed: 1.4ms preprocess, 264.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 214.7ms
# Speed: 1.2ms preprocess, 214.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 264.4ms
# Speed: 1.4ms preprocess, 264.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 217.2ms
# Speed: 1.2ms preprocess, 217.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 270.6ms
# Speed: 1.3ms preprocess, 270.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 217.8ms
# Speed: 1.2ms preprocess, 217.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3929: 감지 - 클래스=car, 신뢰도=0.64, 좌표=(376, 166, 410, 195)
#
# 0: 384x640 1 car, 263.4ms
# Speed: 1.4ms preprocess, 263.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3931: 감지 - 클래스=car, 신뢰도=0.64, 좌표=(373, 166, 409, 194)
#
# 0: 384x640 2 cars, 1 airplane, 214.3ms
# Speed: 1.4ms preprocess, 214.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3933: 감지 - 클래스=car, 신뢰도=0.74, 좌표=(373, 165, 408, 194)
# 프레임 3933: 감지 - 클래스=car, 신뢰도=0.47, 좌표=(414, 167, 442, 185)
#
# 0: 384x640 2 cars, 1 airplane, 1 truck, 269.3ms
# Speed: 1.2ms preprocess, 269.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3935: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(373, 165, 407, 193)
# 프레임 3935: 감지 - 클래스=car, 신뢰도=0.57, 좌표=(414, 166, 441, 184)
# 프레임 3935: 감지 - 클래스=truck, 신뢰도=0.42, 좌표=(309, 167, 360, 201)
#
# 0: 384x640 2 cars, 1 airplane, 2 trucks, 215.3ms
# Speed: 1.2ms preprocess, 215.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3937: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(373, 165, 406, 192)
# 프레임 3937: 감지 - 클래스=car, 신뢰도=0.63, 좌표=(414, 166, 441, 184)
# 프레임 3937: 감지 - 클래스=truck, 신뢰도=0.32, 좌표=(259, 165, 299, 193)
# 프레임 3937: 감지 - 클래스=truck, 신뢰도=0.31, 좌표=(313, 158, 364, 199)
#
# 0: 384x640 2 cars, 267.7ms
# Speed: 1.3ms preprocess, 267.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3939: 감지 - 클래스=car, 신뢰도=0.73, 좌표=(371, 164, 405, 193)
# 프레임 3939: 감지 - 클래스=car, 신뢰도=0.47, 좌표=(413, 166, 441, 183)
#
# 0: 384x640 2 cars, 1 airplane, 1 truck, 217.3ms
# Speed: 1.4ms preprocess, 217.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3941: 감지 - 클래스=car, 신뢰도=0.73, 좌표=(373, 167, 407, 196)
# 프레임 3941: 감지 - 클래스=car, 신뢰도=0.47, 좌표=(413, 167, 440, 187)
# 프레임 3941: 감지 - 클래스=truck, 신뢰도=0.41, 좌표=(259, 166, 298, 197)
#
# 0: 384x640 3 cars, 1 airplane, 265.3ms
# Speed: 1.1ms preprocess, 265.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3943: 감지 - 클래스=car, 신뢰도=0.81, 좌표=(373, 170, 406, 198)
# 프레임 3943: 감지 - 클래스=car, 신뢰도=0.68, 좌표=(414, 171, 440, 189)
# 프레임 3943: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(259, 170, 299, 199)
#
# 0: 384x640 2 cars, 1 airplane, 1 truck, 212.6ms
# Speed: 1.3ms preprocess, 212.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3945: 감지 - 클래스=car, 신뢰도=0.61, 좌표=(373, 171, 404, 199)
# 프레임 3945: 감지 - 클래스=truck, 신뢰도=0.46, 좌표=(260, 171, 300, 200)
# 프레임 3945: 감지 - 클래스=car, 신뢰도=0.45, 좌표=(413, 171, 440, 191)
#
# 0: 384x640 2 cars, 1 airplane, 1 truck, 269.0ms
# Speed: 1.3ms preprocess, 269.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3947: 감지 - 클래스=car, 신뢰도=0.70, 좌표=(371, 173, 404, 200)
# 프레임 3947: 감지 - 클래스=car, 신뢰도=0.53, 좌표=(413, 174, 439, 192)
# 프레임 3947: 감지 - 클래스=truck, 신뢰도=0.36, 좌표=(261, 174, 297, 200)
#
# 0: 384x640 3 cars, 1 airplane, 1 truck, 213.9ms
# Speed: 1.3ms preprocess, 213.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3949: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(371, 175, 403, 203)
# 프레임 3949: 감지 - 클래스=truck, 신뢰도=0.52, 좌표=(261, 175, 299, 203)
# 프레임 3949: 감지 - 클래스=car, 신뢰도=0.42, 좌표=(412, 177, 439, 194)
# 프레임 3949: 감지 - 클래스=car, 신뢰도=0.32, 좌표=(333, 179, 347, 189)
#
# 0: 384x640 4 cars, 1 truck, 269.8ms
# Speed: 1.3ms preprocess, 269.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3951: 감지 - 클래스=car, 신뢰도=0.69, 좌표=(371, 177, 404, 205)
# 프레임 3951: 감지 - 클래스=car, 신뢰도=0.58, 좌표=(261, 179, 299, 206)
# 프레임 3951: 감지 - 클래스=truck, 신뢰도=0.40, 좌표=(261, 179, 300, 206)
# 프레임 3951: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(411, 178, 441, 196)
# 프레임 3951: 감지 - 클래스=car, 신뢰도=0.30, 좌표=(334, 183, 348, 191)
#
# 0: 384x640 3 cars, 1 truck, 212.3ms
# Speed: 1.2ms preprocess, 212.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3953: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(371, 179, 403, 207)
# 프레임 3953: 감지 - 클래스=car, 신뢰도=0.63, 좌표=(411, 179, 438, 197)
# 프레임 3953: 감지 - 클래스=car, 신뢰도=0.50, 좌표=(263, 180, 300, 207)
# 프레임 3953: 감지 - 클래스=truck, 신뢰도=0.44, 좌표=(264, 181, 300, 207)
#
# 0: 384x640 3 cars, 1 truck, 268.2ms
# Speed: 1.3ms preprocess, 268.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3955: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(371, 181, 403, 209)
# 프레임 3955: 감지 - 클래스=car, 신뢰도=0.53, 좌표=(412, 181, 439, 199)
# 프레임 3955: 감지 - 클래스=truck, 신뢰도=0.44, 좌표=(264, 178, 301, 208)
# 프레임 3955: 감지 - 클래스=car, 신뢰도=0.41, 좌표=(264, 180, 300, 207)
#
# 0: 384x640 5 cars, 1 truck, 216.6ms
# Speed: 1.4ms preprocess, 216.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3957: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(370, 183, 401, 211)
# 프레임 3957: 감지 - 클래스=car, 신뢰도=0.59, 좌표=(410, 186, 438, 202)
# 프레임 3957: 감지 - 클래스=car, 신뢰도=0.42, 좌표=(333, 187, 347, 196)
# 프레임 3957: 감지 - 클래스=truck, 신뢰도=0.38, 좌표=(263, 176, 300, 208)
# 프레임 3957: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(263, 178, 300, 208)
# 프레임 3957: 감지 - 클래스=car, 신뢰도=0.35, 좌표=(263, 187, 300, 208)
#
# 0: 384x640 4 cars, 1 airplane, 268.2ms
# Speed: 1.2ms preprocess, 268.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3959: 감지 - 클래스=car, 신뢰도=0.80, 좌표=(368, 186, 399, 213)
# 프레임 3959: 감지 - 클래스=car, 신뢰도=0.68, 좌표=(408, 186, 436, 205)
# 프레임 3959: 감지 - 클래스=car, 신뢰도=0.49, 좌표=(263, 187, 299, 210)
# 프레임 3959: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(332, 188, 345, 198)
#
# 0: 384x640 3 cars, 213.3ms
# Speed: 1.4ms preprocess, 213.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3961: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(369, 188, 399, 216)
# 프레임 3961: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(264, 189, 300, 212)
# 프레임 3961: 감지 - 클래스=car, 신뢰도=0.56, 좌표=(408, 188, 435, 206)
#
# 0: 384x640 4 cars, 264.1ms
# Speed: 1.3ms preprocess, 264.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3963: 감지 - 클래스=car, 신뢰도=0.73, 좌표=(368, 191, 399, 218)
# 프레임 3963: 감지 - 클래스=car, 신뢰도=0.69, 좌표=(264, 190, 300, 214)
# 프레임 3963: 감지 - 클래스=car, 신뢰도=0.61, 좌표=(408, 190, 436, 209)
# 프레임 3963: 감지 - 클래스=car, 신뢰도=0.51, 좌표=(504, 185, 560, 215)
#
# 0: 384x640 5 cars, 1 airplane, 217.8ms
# Speed: 1.4ms preprocess, 217.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3965: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(368, 192, 398, 219)
# 프레임 3965: 감지 - 클래스=car, 신뢰도=0.67, 좌표=(407, 192, 435, 210)
# 프레임 3965: 감지 - 클래스=car, 신뢰도=0.61, 좌표=(264, 192, 300, 216)
# 프레임 3965: 감지 - 클래스=car, 신뢰도=0.40, 좌표=(429, 190, 442, 201)
# 프레임 3965: 감지 - 클래스=car, 신뢰도=0.35, 좌표=(331, 193, 346, 204)
#
# 0: 384x640 5 cars, 1 airplane, 221.7ms
# Speed: 54.0ms preprocess, 221.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3967: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(367, 193, 398, 220)
# 프레임 3967: 감지 - 클래스=car, 신뢰도=0.70, 좌표=(407, 192, 435, 211)
# 프레임 3967: 감지 - 클래스=car, 신뢰도=0.49, 좌표=(264, 193, 299, 217)
# 프레임 3967: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(428, 191, 441, 203)
# 프레임 3967: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(331, 195, 345, 205)
#
# 0: 384x640 5 cars, 271.1ms
# Speed: 1.3ms preprocess, 271.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3969: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(366, 194, 397, 221)
# 프레임 3969: 감지 - 클래스=car, 신뢰도=0.67, 좌표=(503, 189, 563, 219)
# 프레임 3969: 감지 - 클래스=car, 신뢰도=0.59, 좌표=(405, 194, 434, 212)
# 프레임 3969: 감지 - 클래스=car, 신뢰도=0.55, 좌표=(264, 194, 299, 219)
# 프레임 3969: 감지 - 클래스=car, 신뢰도=0.45, 좌표=(428, 191, 440, 204)
#
# 0: 384x640 4 cars, 1 truck, 1 traffic light, 212.3ms
# Speed: 1.3ms preprocess, 212.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3971: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(365, 195, 396, 222)
# 프레임 3971: 감지 - 클래스=car, 신뢰도=0.62, 좌표=(264, 197, 298, 220)
# 프레임 3971: 감지 - 클래스=car, 신뢰도=0.55, 좌표=(405, 195, 434, 214)
# 프레임 3971: 감지 - 클래스=truck, 신뢰도=0.45, 좌표=(505, 190, 565, 220)
# 프레임 3971: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(504, 190, 565, 220)
#
# 0: 384x640 5 cars, 268.9ms
# Speed: 1.2ms preprocess, 268.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3973: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(364, 195, 395, 222)
# 프레임 3973: 감지 - 클래스=car, 신뢰도=0.70, 좌표=(264, 197, 298, 221)
# 프레임 3973: 감지 - 클래스=car, 신뢰도=0.59, 좌표=(405, 196, 434, 214)
# 프레임 3973: 감지 - 클래스=car, 신뢰도=0.55, 좌표=(505, 190, 566, 221)
# 프레임 3973: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(426, 194, 439, 206)
#
# 0: 384x640 4 cars, 228.3ms
# Speed: 1.5ms preprocess, 228.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3975: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(506, 189, 568, 219)
# 프레임 3975: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(263, 197, 298, 221)
# 프레임 3975: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(364, 196, 395, 223)
# 프레임 3975: 감지 - 클래스=car, 신뢰도=0.57, 좌표=(405, 195, 434, 214)
#
# 0: 384x640 5 cars, 1 bus, 219.6ms
# Speed: 50.6ms preprocess, 219.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3977: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(507, 188, 571, 219)
# 프레임 3977: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(264, 198, 299, 222)
# 프레임 3977: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(365, 196, 396, 223)
# 프레임 3977: 감지 - 클래스=bus, 신뢰도=0.63, 좌표=(170, 185, 236, 209)
# 프레임 3977: 감지 - 클래스=car, 신뢰도=0.62, 좌표=(405, 195, 434, 214)
# 프레임 3977: 감지 - 클래스=car, 신뢰도=0.38, 좌표=(426, 194, 440, 205)
#
# 0: 384x640 6 cars, 273.1ms
# Speed: 1.3ms preprocess, 273.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3979: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(365, 196, 397, 222)
# 프레임 3979: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(265, 197, 300, 222)
# 프레임 3979: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(407, 195, 435, 214)
# 프레임 3979: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(510, 187, 574, 218)
# 프레임 3979: 감지 - 클래스=car, 신뢰도=0.53, 좌표=(427, 193, 440, 205)
# 프레임 3979: 감지 - 클래스=car, 신뢰도=0.40, 좌표=(330, 197, 345, 209)
#
# 0: 384x640 6 cars, 1 bus, 215.4ms
# Speed: 1.4ms preprocess, 215.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3981: 감지 - 클래스=car, 신뢰도=0.81, 좌표=(365, 195, 397, 221)
# 프레임 3981: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(266, 197, 300, 220)
# 프레임 3981: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(512, 187, 577, 217)
# 프레임 3981: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(406, 194, 436, 213)
# 프레임 3981: 감지 - 클래스=bus, 신뢰도=0.66, 좌표=(130, 181, 216, 210)
# 프레임 3981: 감지 - 클래스=car, 신뢰도=0.52, 좌표=(428, 192, 441, 205)
# 프레임 3981: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(330, 196, 344, 207)
#
# 0: 384x640 6 cars, 1 bus, 267.4ms
# Speed: 1.3ms preprocess, 267.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3983: 감지 - 클래스=car, 신뢰도=0.81, 좌표=(365, 195, 397, 221)
# 프레임 3983: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(407, 195, 436, 213)
# 프레임 3983: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(514, 188, 580, 219)
# 프레임 3983: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(266, 197, 300, 220)
# 프레임 3983: 감지 - 클래스=bus, 신뢰도=0.74, 좌표=(103, 177, 204, 210)
# 프레임 3983: 감지 - 클래스=car, 신뢰도=0.60, 좌표=(428, 192, 441, 205)
# 프레임 3983: 감지 - 클래스=car, 신뢰도=0.35, 좌표=(330, 196, 344, 207)
#
# 0: 384x640 6 cars, 1 bus, 215.5ms
# Speed: 1.4ms preprocess, 215.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3985: 감지 - 클래스=car, 신뢰도=0.84, 좌표=(515, 188, 583, 220)
# 프레임 3985: 감지 - 클래스=car, 신뢰도=0.82, 좌표=(366, 195, 399, 222)
# 프레임 3985: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(407, 195, 437, 214)
# 프레임 3985: 감지 - 클래스=bus, 신뢰도=0.78, 좌표=(70, 175, 189, 210)
# 프레임 3985: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(267, 197, 300, 220)
# 프레임 3985: 감지 - 클래스=car, 신뢰도=0.51, 좌표=(428, 194, 442, 206)
# 프레임 3985: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(330, 196, 345, 207)
#
# 0: 384x640 5 cars, 1 bus, 265.2ms
# Speed: 1.3ms preprocess, 265.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3987: 감지 - 클래스=car, 신뢰도=0.86, 좌표=(518, 189, 587, 222)
# 프레임 3987: 감지 - 클래스=car, 신뢰도=0.82, 좌표=(367, 196, 400, 223)
# 프레임 3987: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(268, 197, 302, 220)
# 프레임 3987: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(408, 196, 439, 215)
# 프레임 3987: 감지 - 클래스=bus, 신뢰도=0.39, 좌표=(28, 171, 173, 211)
# 프레임 3987: 감지 - 클래스=car, 신뢰도=0.30, 좌표=(429, 194, 443, 207)
#
# 0: 384x640 4 cars, 214.7ms
# Speed: 1.5ms preprocess, 214.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3989: 감지 - 클래스=car, 신뢰도=0.84, 좌표=(519, 189, 589, 222)
# 프레임 3989: 감지 - 클래스=car, 신뢰도=0.82, 좌표=(367, 196, 399, 222)
# 프레임 3989: 감지 - 클래스=car, 신뢰도=0.73, 좌표=(267, 197, 301, 220)
# 프레임 3989: 감지 - 클래스=car, 신뢰도=0.71, 좌표=(408, 196, 438, 215)
#
# 0: 384x640 4 cars, 268.6ms
# Speed: 1.2ms preprocess, 268.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3991: 감지 - 클래스=car, 신뢰도=0.86, 좌표=(520, 187, 591, 220)
# 프레임 3991: 감지 - 클래스=car, 신뢰도=0.82, 좌표=(366, 195, 398, 221)
# 프레임 3991: 감지 - 클래스=car, 신뢰도=0.74, 좌표=(408, 195, 438, 214)
# 프레임 3991: 감지 - 클래스=car, 신뢰도=0.71, 좌표=(267, 200, 300, 219)
#
# 0: 384x640 5 cars, 1 bus, 214.8ms
# Speed: 1.2ms preprocess, 214.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3993: 감지 - 클래스=car, 신뢰도=0.87, 좌표=(523, 184, 595, 218)
# 프레임 3993: 감지 - 클래스=car, 신뢰도=0.82, 좌표=(367, 194, 398, 220)
# 프레임 3993: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(268, 195, 301, 218)
# 프레임 3993: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(409, 193, 439, 212)
# 프레임 3993: 감지 - 클래스=bus, 신뢰도=0.64, 좌표=(0, 169, 88, 212)
# 프레임 3993: 감지 - 클래스=car, 신뢰도=0.33, 좌표=(329, 193, 344, 206)
#
# 0: 384x640 5 cars, 265.4ms
# Speed: 1.2ms preprocess, 265.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3995: 감지 - 클래스=car, 신뢰도=0.87, 좌표=(524, 182, 598, 218)
# 프레임 3995: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(367, 193, 399, 220)
# 프레임 3995: 감지 - 클래스=car, 신뢰도=0.68, 좌표=(268, 196, 301, 218)
# 프레임 3995: 감지 - 클래스=car, 신뢰도=0.67, 좌표=(410, 193, 440, 212)
# 프레임 3995: 감지 - 클래스=car, 신뢰도=0.32, 좌표=(330, 194, 344, 206)
#
# 0: 384x640 4 cars, 213.5ms
# Speed: 1.2ms preprocess, 213.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3997: 감지 - 클래스=car, 신뢰도=0.86, 좌표=(526, 184, 602, 219)
# 프레임 3997: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(367, 194, 399, 221)
# 프레임 3997: 감지 - 클래스=car, 신뢰도=0.73, 좌표=(410, 193, 440, 213)
# 프레임 3997: 감지 - 클래스=car, 신뢰도=0.68, 좌표=(268, 200, 301, 219)
#
# 0: 384x640 4 cars, 268.3ms
# Speed: 1.3ms preprocess, 268.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 3999: 감지 - 클래스=car, 신뢰도=0.86, 좌표=(529, 180, 606, 220)
# 프레임 3999: 감지 - 클래스=car, 신뢰도=0.80, 좌표=(368, 195, 399, 222)
# 프레임 3999: 감지 - 클래스=car, 신뢰도=0.74, 좌표=(411, 193, 441, 214)
# 프레임 3999: 감지 - 클래스=car, 신뢰도=0.73, 좌표=(268, 197, 301, 220)
#
# 0: 384x640 7 cars, 215.6ms
# Speed: 1.2ms preprocess, 215.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4001: 감지 - 클래스=car, 신뢰도=0.89, 좌표=(533, 185, 611, 221)
# 프레임 4001: 감지 - 클래스=car, 신뢰도=0.80, 좌표=(369, 195, 400, 222)
# 프레임 4001: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(269, 197, 302, 220)
# 프레임 4001: 감지 - 클래스=car, 신뢰도=0.69, 좌표=(412, 193, 443, 214)
# 프레임 4001: 감지 - 클래스=car, 신뢰도=0.38, 좌표=(8, 253, 638, 356)
# 프레임 4001: 감지 - 클래스=car, 신뢰도=0.37, 좌표=(403, 194, 417, 203)
# 프레임 4001: 감지 - 클래스=car, 신뢰도=0.35, 좌표=(331, 198, 344, 207)
#
# 0: 384x640 4 cars, 262.7ms
# Speed: 1.3ms preprocess, 262.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4003: 감지 - 클래스=car, 신뢰도=0.89, 좌표=(535, 185, 616, 221)
# 프레임 4003: 감지 - 클래스=car, 신뢰도=0.81, 좌표=(369, 196, 401, 222)
# 프레임 4003: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(270, 197, 303, 221)
# 프레임 4003: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(413, 193, 444, 214)
#
# 0: 384x640 6 cars, 212.3ms
# Speed: 1.2ms preprocess, 212.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4005: 감지 - 클래스=car, 신뢰도=0.88, 좌표=(537, 181, 620, 219)
# 프레임 4005: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(414, 192, 445, 214)
# 프레임 4005: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(370, 194, 401, 222)
# 프레임 4005: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(270, 197, 303, 221)
# 프레임 4005: 감지 - 클래스=car, 신뢰도=0.47, 좌표=(402, 193, 416, 203)
# 프레임 4005: 감지 - 클래스=car, 신뢰도=0.33, 좌표=(331, 198, 344, 207)
#
# 0: 384x640 6 cars, 273.2ms
# Speed: 1.3ms preprocess, 273.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4007: 감지 - 클래스=car, 신뢰도=0.87, 좌표=(540, 179, 626, 217)
# 프레임 4007: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(415, 190, 446, 212)
# 프레임 4007: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(370, 193, 402, 220)
# 프레임 4007: 감지 - 클래스=car, 신뢰도=0.66, 좌표=(271, 196, 303, 219)
# 프레임 4007: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(331, 197, 344, 206)
# 프레임 4007: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(401, 192, 417, 201)
#
# 0: 384x640 5 cars, 1 truck, 216.7ms
# Speed: 1.8ms preprocess, 216.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4009: 감지 - 클래스=car, 신뢰도=0.87, 좌표=(543, 175, 632, 213)
# 프레임 4009: 감지 - 클래스=car, 신뢰도=0.80, 좌표=(371, 191, 403, 218)
# 프레임 4009: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(415, 188, 448, 210)
# 프레임 4009: 감지 - 클래스=car, 신뢰도=0.50, 좌표=(271, 195, 304, 219)
# 프레임 4009: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(331, 197, 344, 205)
# 프레임 4009: 감지 - 클래스=truck, 신뢰도=0.33, 좌표=(271, 195, 304, 219)
#
# 0: 384x640 4 cars, 266.1ms
# Speed: 1.2ms preprocess, 266.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4011: 감지 - 클래스=car, 신뢰도=0.87, 좌표=(547, 172, 638, 211)
# 프레임 4011: 감지 - 클래스=car, 신뢰도=0.81, 좌표=(372, 191, 405, 218)
# 프레임 4011: 감지 - 클래스=car, 신뢰도=0.70, 좌표=(416, 187, 449, 209)
# 프레임 4011: 감지 - 클래스=car, 신뢰도=0.56, 좌표=(272, 196, 304, 219)
#
# 0: 384x640 4 cars, 210.8ms
# Speed: 1.4ms preprocess, 210.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4013: 감지 - 클래스=car, 신뢰도=0.85, 좌표=(551, 168, 639, 209)
# 프레임 4013: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(373, 190, 406, 217)
# 프레임 4013: 감지 - 클래스=car, 신뢰도=0.58, 좌표=(417, 186, 451, 209)
# 프레임 4013: 감지 - 클래스=car, 신뢰도=0.58, 좌표=(272, 197, 305, 220)
#
# 0: 384x640 4 cars, 267.0ms
# Speed: 1.5ms preprocess, 267.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4015: 감지 - 클래스=car, 신뢰도=0.86, 좌표=(555, 166, 639, 208)
# 프레임 4015: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(375, 189, 407, 218)
# 프레임 4015: 감지 - 클래스=car, 신뢰도=0.67, 좌표=(419, 185, 453, 208)
# 프레임 4015: 감지 - 클래스=car, 신뢰도=0.65, 좌표=(273, 196, 306, 221)
#
# 0: 384x640 5 cars, 215.9ms
# Speed: 1.2ms preprocess, 215.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4017: 감지 - 클래스=car, 신뢰도=0.83, 좌표=(560, 165, 639, 208)
# 프레임 4017: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(376, 189, 409, 217)
# 프레임 4017: 감지 - 클래스=car, 신뢰도=0.70, 좌표=(421, 185, 456, 208)
# 프레임 4017: 감지 - 클래스=car, 신뢰도=0.67, 좌표=(274, 195, 307, 219)
# 프레임 4017: 감지 - 클래스=car, 신뢰도=0.42, 좌표=(332, 195, 346, 204)
#
# 0: 384x640 5 cars, 264.7ms
# Speed: 1.3ms preprocess, 264.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4019: 감지 - 클래스=car, 신뢰도=0.88, 좌표=(564, 167, 639, 209)
# 프레임 4019: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(378, 188, 411, 217)
# 프레임 4019: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(422, 185, 458, 208)
# 프레임 4019: 감지 - 클래스=car, 신뢰도=0.62, 좌표=(275, 194, 308, 219)
# 프레임 4019: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(333, 195, 346, 204)
#
# 0: 384x640 5 cars, 214.2ms
# Speed: 1.3ms preprocess, 214.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4021: 감지 - 클래스=car, 신뢰도=0.86, 좌표=(569, 166, 639, 210)
# 프레임 4021: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(378, 188, 412, 216)
# 프레임 4021: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(426, 184, 459, 208)
# 프레임 4021: 감지 - 클래스=car, 신뢰도=0.58, 좌표=(275, 194, 308, 218)
# 프레임 4021: 감지 - 클래스=car, 신뢰도=0.39, 좌표=(334, 194, 346, 203)
#
# 0: 384x640 5 cars, 266.4ms
# Speed: 1.3ms preprocess, 266.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4023: 감지 - 클래스=car, 신뢰도=0.85, 좌표=(573, 168, 639, 211)
# 프레임 4023: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(378, 188, 413, 217)
# 프레임 4023: 감지 - 클래스=car, 신뢰도=0.74, 좌표=(425, 185, 461, 208)
# 프레임 4023: 감지 - 클래스=car, 신뢰도=0.55, 좌표=(275, 194, 308, 218)
# 프레임 4023: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(334, 195, 346, 203)
#
# 0: 384x640 6 cars, 217.9ms
# Speed: 1.2ms preprocess, 217.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4025: 감지 - 클래스=car, 신뢰도=0.82, 좌표=(379, 189, 414, 218)
# 프레임 4025: 감지 - 클래스=car, 신뢰도=0.81, 좌표=(578, 168, 639, 212)
# 프레임 4025: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(426, 186, 463, 209)
# 프레임 4025: 감지 - 클래스=car, 신뢰도=0.65, 좌표=(275, 194, 308, 219)
# 프레임 4025: 감지 - 클래스=car, 신뢰도=0.38, 좌표=(334, 196, 346, 204)
# 프레임 4025: 감지 - 클래스=car, 신뢰도=0.37, 좌표=(406, 188, 418, 197)
#
# 0: 384x640 5 cars, 265.3ms
# Speed: 1.6ms preprocess, 265.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4027: 감지 - 클래스=car, 신뢰도=0.87, 좌표=(583, 170, 639, 214)
# 프레임 4027: 감지 - 클래스=car, 신뢰도=0.83, 좌표=(381, 190, 415, 218)
# 프레임 4027: 감지 - 클래스=car, 신뢰도=0.81, 좌표=(427, 186, 465, 210)
# 프레임 4027: 감지 - 클래스=car, 신뢰도=0.68, 좌표=(276, 196, 309, 219)
# 프레임 4027: 감지 - 클래스=car, 신뢰도=0.30, 좌표=(376, 193, 385, 203)
#
# 0: 384x640 6 cars, 212.0ms
# Speed: 1.3ms preprocess, 212.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4029: 감지 - 클래스=car, 신뢰도=0.85, 좌표=(589, 172, 639, 214)
# 프레임 4029: 감지 - 클래스=car, 신뢰도=0.81, 좌표=(382, 191, 417, 219)
# 프레임 4029: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(429, 187, 467, 211)
# 프레임 4029: 감지 - 클래스=car, 신뢰도=0.69, 좌표=(277, 197, 310, 220)
# 프레임 4029: 감지 - 클래스=car, 신뢰도=0.45, 좌표=(377, 193, 385, 203)
# 프레임 4029: 감지 - 클래스=car, 신뢰도=0.43, 좌표=(335, 198, 347, 206)
#
# 0: 384x640 6 cars, 266.6ms
# Speed: 1.3ms preprocess, 266.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4031: 감지 - 클래스=car, 신뢰도=0.85, 좌표=(594, 173, 639, 214)
# 프레임 4031: 감지 - 클래스=car, 신뢰도=0.81, 좌표=(384, 191, 418, 220)
# 프레임 4031: 감지 - 클래스=car, 신뢰도=0.80, 좌표=(431, 188, 470, 212)
# 프레임 4031: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(277, 196, 310, 221)
# 프레임 4031: 감지 - 클래스=car, 신뢰도=0.42, 좌표=(376, 193, 387, 204)
# 프레임 4031: 감지 - 클래스=car, 신뢰도=0.39, 좌표=(335, 200, 347, 207)
#
# 0: 384x640 6 cars, 215.2ms
# Speed: 1.8ms preprocess, 215.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4033: 감지 - 클래스=car, 신뢰도=0.83, 좌표=(600, 173, 639, 214)
# 프레임 4033: 감지 - 클래스=car, 신뢰도=0.81, 좌표=(384, 191, 419, 221)
# 프레임 4033: 감지 - 클래스=car, 신뢰도=0.80, 좌표=(431, 188, 472, 212)
# 프레임 4033: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(277, 197, 311, 222)
# 프레임 4033: 감지 - 클래스=car, 신뢰도=0.51, 좌표=(377, 193, 387, 205)
# 프레임 4033: 감지 - 클래스=car, 신뢰도=0.45, 좌표=(335, 200, 347, 207)
#
# 0: 384x640 6 cars, 269.9ms
# Speed: 1.2ms preprocess, 269.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4035: 감지 - 클래스=car, 신뢰도=0.83, 좌표=(431, 188, 473, 212)
# 프레임 4035: 감지 - 클래스=car, 신뢰도=0.83, 좌표=(385, 191, 420, 221)
# 프레임 4035: 감지 - 클래스=car, 신뢰도=0.74, 좌표=(605, 176, 639, 214)
# 프레임 4035: 감지 - 클래스=car, 신뢰도=0.59, 좌표=(277, 197, 310, 222)
# 프레임 4035: 감지 - 클래스=car, 신뢰도=0.48, 좌표=(377, 193, 388, 204)
# 프레임 4035: 감지 - 클래스=car, 신뢰도=0.39, 좌표=(334, 200, 346, 208)
#
# 0: 384x640 7 cars, 214.9ms
# Speed: 1.3ms preprocess, 214.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4037: 감지 - 클래스=car, 신뢰도=0.85, 좌표=(385, 191, 421, 221)
# 프레임 4037: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(431, 188, 475, 213)
# 프레임 4037: 감지 - 클래스=car, 신뢰도=0.68, 좌표=(276, 198, 310, 223)
# 프레임 4037: 감지 - 클래스=car, 신뢰도=0.65, 좌표=(610, 185, 639, 214)
# 프레임 4037: 감지 - 클래스=car, 신뢰도=0.58, 좌표=(376, 194, 388, 206)
# 프레임 4037: 감지 - 클래스=car, 신뢰도=0.33, 좌표=(333, 200, 345, 208)
# 프레임 4037: 감지 - 클래스=car, 신뢰도=0.33, 좌표=(355, 195, 367, 205)
#
# 0: 384x640 5 cars, 1 truck, 267.8ms
# Speed: 1.5ms preprocess, 267.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4039: 감지 - 클래스=car, 신뢰도=0.85, 좌표=(386, 191, 421, 222)
# 프레임 4039: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(275, 198, 309, 223)
# 프레임 4039: 감지 - 클래스=car, 신뢰도=0.70, 좌표=(433, 188, 476, 214)
# 프레임 4039: 감지 - 클래스=car, 신뢰도=0.57, 좌표=(375, 194, 388, 206)
# 프레임 4039: 감지 - 클래스=car, 신뢰도=0.39, 좌표=(614, 185, 639, 214)
# 프레임 4039: 감지 - 클래스=truck, 신뢰도=0.34, 좌표=(614, 185, 639, 214)
#
# 0: 384x640 7 cars, 1 truck, 217.2ms
# Speed: 1.6ms preprocess, 217.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4041: 감지 - 클래스=car, 신뢰도=0.84, 좌표=(386, 191, 423, 222)
# 프레임 4041: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(436, 189, 478, 213)
# 프레임 4041: 감지 - 클래스=car, 신뢰도=0.62, 좌표=(275, 197, 309, 223)
# 프레임 4041: 감지 - 클래스=car, 신뢰도=0.59, 좌표=(374, 194, 388, 206)
# 프레임 4041: 감지 - 클래스=truck, 신뢰도=0.36, 좌표=(621, 184, 639, 214)
# 프레임 4041: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(621, 184, 639, 214)
# 프레임 4041: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(428, 189, 447, 205)
# 프레임 4041: 감지 - 클래스=car, 신뢰도=0.30, 좌표=(353, 196, 365, 205)
#
# 0: 384x640 6 cars, 212.8ms
# Speed: 51.1ms preprocess, 212.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4043: 감지 - 클래스=car, 신뢰도=0.86, 좌표=(386, 189, 424, 220)
# 프레임 4043: 감지 - 클래스=car, 신뢰도=0.82, 좌표=(436, 186, 480, 212)
# 프레임 4043: 감지 - 클래스=car, 신뢰도=0.61, 좌표=(274, 196, 308, 220)
# 프레임 4043: 감지 - 클래스=car, 신뢰도=0.58, 좌표=(373, 193, 387, 203)
# 프레임 4043: 감지 - 클래스=car, 신뢰도=0.48, 좌표=(627, 182, 639, 214)
# 프레임 4043: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(427, 187, 447, 203)
#
# 0: 384x640 5 cars, 214.3ms
# Speed: 1.3ms preprocess, 214.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4045: 감지 - 클래스=car, 신뢰도=0.83, 좌표=(386, 186, 423, 217)
# 프레임 4045: 감지 - 클래스=car, 신뢰도=0.74, 좌표=(437, 185, 481, 210)
# 프레임 4045: 감지 - 클래스=car, 신뢰도=0.46, 좌표=(426, 184, 447, 200)
# 프레임 4045: 감지 - 클래스=car, 신뢰도=0.40, 좌표=(273, 198, 306, 217)
# 프레임 4045: 감지 - 클래스=car, 신뢰도=0.33, 좌표=(371, 191, 388, 200)
#
# 0: 384x640 7 cars, 269.4ms
# Speed: 1.2ms preprocess, 269.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4047: 감지 - 클래스=car, 신뢰도=0.86, 좌표=(386, 185, 423, 216)
# 프레임 4047: 감지 - 클래스=car, 신뢰도=0.84, 좌표=(436, 181, 482, 208)
# 프레임 4047: 감지 - 클래스=car, 신뢰도=0.62, 좌표=(271, 191, 305, 217)
# 프레임 4047: 감지 - 클래스=car, 신뢰도=0.49, 좌표=(425, 183, 445, 199)
# 프레임 4047: 감지 - 클래스=car, 신뢰도=0.38, 좌표=(348, 190, 360, 199)
# 프레임 4047: 감지 - 클래스=car, 신뢰도=0.38, 좌표=(326, 194, 339, 202)
# 프레임 4047: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(370, 187, 386, 199)
#
# 0: 384x640 7 cars, 218.0ms
# Speed: 1.2ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4049: 감지 - 클래스=car, 신뢰도=0.84, 좌표=(387, 184, 425, 216)
# 프레임 4049: 감지 - 클래스=car, 신뢰도=0.84, 좌표=(439, 179, 485, 208)
# 프레임 4049: 감지 - 클래스=car, 신뢰도=0.60, 좌표=(272, 192, 305, 217)
# 프레임 4049: 감지 - 클래스=car, 신뢰도=0.56, 좌표=(426, 181, 447, 198)
# 프레임 4049: 감지 - 클래스=car, 신뢰도=0.48, 좌표=(3, 224, 638, 355)
# 프레임 4049: 감지 - 클래스=car, 신뢰도=0.44, 좌표=(326, 195, 339, 202)
# 프레임 4049: 감지 - 클래스=car, 신뢰도=0.35, 좌표=(347, 189, 359, 199)
#
# 0: 384x640 8 cars, 215.1ms
# Speed: 50.5ms preprocess, 215.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4051: 감지 - 클래스=car, 신뢰도=0.84, 좌표=(389, 185, 428, 216)
# 프레임 4051: 감지 - 클래스=car, 신뢰도=0.83, 좌표=(441, 179, 489, 208)
# 프레임 4051: 감지 - 클래스=car, 신뢰도=0.59, 좌표=(272, 194, 306, 218)
# 프레임 4051: 감지 - 클래스=car, 신뢰도=0.57, 좌표=(3, 232, 638, 355)
# 프레임 4051: 감지 - 클래스=car, 신뢰도=0.52, 좌표=(426, 182, 449, 198)
# 프레임 4051: 감지 - 클래스=car, 신뢰도=0.50, 좌표=(326, 195, 339, 203)
# 프레임 4051: 감지 - 클래스=car, 신뢰도=0.37, 좌표=(381, 187, 391, 198)
# 프레임 4051: 감지 - 클래스=car, 신뢰도=0.35, 좌표=(347, 190, 359, 200)
#
# 0: 384x640 9 cars, 215.7ms
# Speed: 1.3ms preprocess, 215.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4053: 감지 - 클래스=car, 신뢰도=0.88, 좌표=(390, 185, 430, 217)
# 프레임 4053: 감지 - 클래스=car, 신뢰도=0.85, 좌표=(443, 181, 493, 210)
# 프레임 4053: 감지 - 클래스=car, 신뢰도=0.67, 좌표=(272, 194, 307, 219)
# 프레임 4053: 감지 - 클래스=car, 신뢰도=0.58, 좌표=(427, 183, 451, 199)
# 프레임 4053: 감지 - 클래스=car, 신뢰도=0.45, 좌표=(4, 235, 638, 354)
# 프레임 4053: 감지 - 클래스=car, 신뢰도=0.44, 좌표=(370, 189, 386, 201)
# 프레임 4053: 감지 - 클래스=car, 신뢰도=0.43, 좌표=(326, 196, 338, 204)
# 프레임 4053: 감지 - 클래스=car, 신뢰도=0.32, 좌표=(348, 191, 359, 200)
# 프레임 4053: 감지 - 클래스=car, 신뢰도=0.32, 좌표=(383, 188, 394, 200)
#
# 0: 384x640 8 cars, 1 truck, 215.7ms
# Speed: 1.5ms preprocess, 215.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4055: 감지 - 클래스=car, 신뢰도=0.82, 좌표=(392, 186, 433, 218)
# 프레임 4055: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(447, 182, 497, 211)
# ...
# 프레임 4885: 감지 - 클래스=car, 신뢰도=0.83, 좌표=(382, 121, 428, 155)
# 프레임 4885: 감지 - 클래스=car, 신뢰도=0.73, 좌표=(278, 127, 304, 146)
# 프레임 4885: 감지 - 클래스=car, 신뢰도=0.70, 좌표=(314, 120, 359, 159)
# 프레임 4885: 감지 - 클래스=car, 신뢰도=0.41, 좌표=(299, 125, 312, 138)
# 프레임 4885: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(187, 108, 216, 127)
# 프레임 4885: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(358, 124, 374, 136)
#
# 0: 384x640 4 cars, 218.0ms
# Speed: 1.2ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4887: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(381, 120, 427, 153)
# 프레임 4887: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(277, 126, 304, 145)
# 프레임 4887: 감지 - 클래스=car, 신뢰도=0.67, 좌표=(314, 119, 358, 157)
# 프레임 4887: 감지 - 클래스=car, 신뢰도=0.35, 좌표=(358, 125, 373, 134)
#
# 0: 384x640 3 cars, 214.1ms
# Speed: 54.1ms preprocess, 214.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4889: 감지 - 클래스=car, 신뢰도=0.82, 좌표=(381, 118, 427, 152)
# 프레임 4889: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(277, 125, 303, 144)
# 프레임 4889: 감지 - 클래스=car, 신뢰도=0.61, 좌표=(313, 119, 357, 156)
#
# 0: 384x640 5 cars, 211.1ms
# Speed: 1.2ms preprocess, 211.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4891: 감지 - 클래스=car, 신뢰도=0.84, 좌표=(380, 117, 427, 151)
# 프레임 4891: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(277, 124, 303, 143)
# 프레임 4891: 감지 - 클래스=car, 신뢰도=0.63, 좌표=(313, 118, 357, 155)
# 프레임 4891: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(0, 56, 617, 352)
# 프레임 4891: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(358, 123, 373, 133)
#
# 0: 384x640 4 cars, 1 bus, 276.0ms
# Speed: 1.2ms preprocess, 276.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4893: 감지 - 클래스=car, 신뢰도=0.84, 좌표=(381, 117, 427, 150)
# 프레임 4893: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(278, 123, 304, 141)
# 프레임 4893: 감지 - 클래스=car, 신뢰도=0.66, 좌표=(313, 117, 357, 153)
# 프레임 4893: 감지 - 클래스=bus, 신뢰도=0.38, 좌표=(140, 99, 210, 124)
# 프레임 4893: 감지 - 클래스=car, 신뢰도=0.33, 좌표=(0, 52, 619, 352)
#
# 0: 384x640 5 cars, 276.7ms
# Speed: 1.3ms preprocess, 276.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4895: 감지 - 클래스=car, 신뢰도=0.86, 좌표=(381, 115, 427, 149)
# 프레임 4895: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(278, 121, 304, 140)
# 프레임 4895: 감지 - 클래스=car, 신뢰도=0.63, 좌표=(314, 115, 358, 152)
# 프레임 4895: 감지 - 클래스=car, 신뢰도=0.42, 좌표=(0, 48, 618, 353)
# 프레임 4895: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(298, 120, 312, 133)
#
# 0: 384x640 5 cars, 222.6ms
# Speed: 1.2ms preprocess, 222.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4897: 감지 - 클래스=car, 신뢰도=0.85, 좌표=(382, 115, 427, 148)
# 프레임 4897: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(279, 120, 304, 139)
# 프레임 4897: 감지 - 클래스=car, 신뢰도=0.53, 좌표=(314, 115, 358, 151)
# 프레임 4897: 감지 - 클래스=car, 신뢰도=0.40, 좌표=(0, 36, 618, 355)
# 프레임 4897: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(359, 115, 373, 128)
#
# 0: 384x640 5 cars, 264.2ms
# Speed: 1.2ms preprocess, 264.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4899: 감지 - 클래스=car, 신뢰도=0.85, 좌표=(381, 114, 426, 147)
# 프레임 4899: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(279, 121, 304, 139)
# 프레임 4899: 감지 - 클래스=car, 신뢰도=0.51, 좌표=(314, 115, 358, 150)
# 프레임 4899: 감지 - 클래스=car, 신뢰도=0.35, 좌표=(0, 38, 616, 352)
# 프레임 4899: 감지 - 클래스=car, 신뢰도=0.33, 좌표=(357, 114, 372, 129)
#
# 0: 384x640 5 cars, 1 truck, 226.0ms
# Speed: 1.3ms preprocess, 226.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4901: 감지 - 클래스=car, 신뢰도=0.84, 좌표=(381, 115, 425, 147)
# 프레임 4901: 감지 - 클래스=car, 신뢰도=0.80, 좌표=(278, 122, 304, 139)
# 프레임 4901: 감지 - 클래스=car, 신뢰도=0.52, 좌표=(314, 115, 357, 150)
# 프레임 4901: 감지 - 클래스=car, 신뢰도=0.40, 좌표=(0, 45, 616, 352)
# 프레임 4901: 감지 - 클래스=car, 신뢰도=0.38, 좌표=(357, 114, 371, 129)
# 프레임 4901: 감지 - 클래스=truck, 신뢰도=0.37, 좌표=(313, 115, 357, 151)
#
# 0: 384x640 5 cars, 221.1ms
# Speed: 1.5ms preprocess, 221.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4903: 감지 - 클래스=car, 신뢰도=0.85, 좌표=(381, 115, 425, 147)
# 프레임 4903: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(279, 122, 304, 140)
# 프레임 4903: 감지 - 클래스=car, 신뢰도=0.57, 좌표=(314, 115, 357, 150)
# 프레임 4903: 감지 - 클래스=car, 신뢰도=0.50, 좌표=(0, 50, 619, 353)
# 프레임 4903: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(358, 114, 372, 129)
#
# 0: 384x640 6 cars, 276.9ms
# Speed: 1.2ms preprocess, 276.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4905: 감지 - 클래스=car, 신뢰도=0.85, 좌표=(381, 114, 425, 147)
# 프레임 4905: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(279, 122, 305, 139)
# 프레임 4905: 감지 - 클래스=car, 신뢰도=0.70, 좌표=(314, 115, 357, 150)
# 프레임 4905: 감지 - 클래스=car, 신뢰도=0.51, 좌표=(1, 39, 619, 354)
# 프레임 4905: 감지 - 클래스=car, 신뢰도=0.48, 좌표=(263, 112, 278, 121)
# 프레임 4905: 감지 - 클래스=car, 신뢰도=0.33, 좌표=(356, 115, 372, 130)
#
# 0: 384x640 6 cars, 213.1ms
# Speed: 1.2ms preprocess, 213.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4907: 감지 - 클래스=car, 신뢰도=0.86, 좌표=(381, 115, 425, 146)
# 프레임 4907: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(280, 121, 305, 139)
# 프레임 4907: 감지 - 클래스=car, 신뢰도=0.69, 좌표=(314, 115, 357, 150)
# 프레임 4907: 감지 - 클래스=car, 신뢰도=0.48, 좌표=(0, 28, 618, 355)
# 프레임 4907: 감지 - 클래스=car, 신뢰도=0.43, 좌표=(261, 111, 277, 121)
# 프레임 4907: 감지 - 클래스=car, 신뢰도=0.33, 좌표=(356, 114, 371, 130)
#
# 0: 384x640 5 cars, 270.3ms
# Speed: 1.2ms preprocess, 270.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4909: 감지 - 클래스=car, 신뢰도=0.83, 좌표=(381, 116, 425, 148)
# 프레임 4909: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(280, 121, 305, 139)
# 프레임 4909: 감지 - 클래스=car, 신뢰도=0.57, 좌표=(315, 115, 357, 150)
# 프레임 4909: 감지 - 클래스=car, 신뢰도=0.44, 좌표=(0, 29, 616, 354)
# 프레임 4909: 감지 - 클래스=car, 신뢰도=0.40, 좌표=(259, 111, 278, 121)
#
# 0: 384x640 4 cars, 1 truck, 212.7ms
# Speed: 1.2ms preprocess, 212.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4911: 감지 - 클래스=car, 신뢰도=0.83, 좌표=(382, 118, 425, 150)
# 프레임 4911: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(281, 122, 306, 140)
# 프레임 4911: 감지 - 클래스=truck, 신뢰도=0.66, 좌표=(315, 117, 356, 152)
# 프레임 4911: 감지 - 클래스=car, 신뢰도=0.44, 좌표=(0, 25, 605, 354)
# 프레임 4911: 감지 - 클래스=car, 신뢰도=0.37, 좌표=(257, 112, 277, 123)
#
# 0: 384x640 4 cars, 1 truck, 265.7ms
# Speed: 1.2ms preprocess, 265.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4913: 감지 - 클래스=car, 신뢰도=0.80, 좌표=(281, 123, 306, 141)
# 프레임 4913: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(381, 119, 425, 150)
# 프레임 4913: 감지 - 클래스=truck, 신뢰도=0.58, 좌표=(315, 118, 356, 153)
# 프레임 4913: 감지 - 클래스=car, 신뢰도=0.46, 좌표=(0, 26, 617, 353)
# 프레임 4913: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(316, 118, 356, 153)
#
# 0: 384x640 6 cars, 207.8ms
# Speed: 1.3ms preprocess, 207.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4915: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(280, 125, 305, 143)
# 프레임 4915: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(381, 121, 424, 151)
# 프레임 4915: 감지 - 클래스=car, 신뢰도=0.66, 좌표=(315, 120, 356, 155)
# 프레임 4915: 감지 - 클래스=car, 신뢰도=0.40, 좌표=(249, 115, 265, 126)
# 프레임 4915: 감지 - 클래스=car, 신뢰도=0.32, 좌표=(297, 124, 312, 136)
# 프레임 4915: 감지 - 클래스=car, 신뢰도=0.30, 좌표=(0, 38, 618, 353)
#
# 0: 384x640 6 cars, 265.7ms
# Speed: 1.2ms preprocess, 265.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4917: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(280, 128, 305, 146)
# 프레임 4917: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(380, 121, 424, 153)
# 프레임 4917: 감지 - 클래스=car, 신뢰도=0.65, 좌표=(315, 123, 355, 157)
# 프레임 4917: 감지 - 클래스=car, 신뢰도=0.45, 좌표=(246, 118, 262, 129)
# 프레임 4917: 감지 - 클래스=car, 신뢰도=0.33, 좌표=(356, 121, 371, 136)
# 프레임 4917: 감지 - 클래스=car, 신뢰도=0.32, 좌표=(0, 41, 618, 353)
#
# 0: 384x640 5 cars, 213.3ms
# Speed: 1.3ms preprocess, 213.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4919: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(280, 129, 305, 147)
# 프레임 4919: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(380, 123, 424, 154)
# 프레임 4919: 감지 - 클래스=car, 신뢰도=0.71, 좌표=(314, 125, 355, 158)
# 프레임 4919: 감지 - 클래스=car, 신뢰도=0.45, 좌표=(0, 3, 618, 353)
# 프레임 4919: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(299, 128, 312, 140)
#
# 0: 384x640 5 cars, 265.5ms
# Speed: 1.2ms preprocess, 265.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4921: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(380, 125, 423, 156)
# 프레임 4921: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(280, 130, 304, 147)
# 프레임 4921: 감지 - 클래스=car, 신뢰도=0.68, 좌표=(314, 127, 354, 160)
# 프레임 4921: 감지 - 클래스=car, 신뢰도=0.35, 좌표=(0, 10, 613, 353)
# 프레임 4921: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(300, 129, 311, 141)
#
# 0: 384x640 5 cars, 208.0ms
# Speed: 1.2ms preprocess, 208.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4923: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(380, 126, 423, 157)
# 프레임 4923: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(280, 132, 304, 149)
# 프레임 4923: 감지 - 클래스=car, 신뢰도=0.65, 좌표=(314, 128, 355, 161)
# 프레임 4923: 감지 - 클래스=car, 신뢰도=0.32, 좌표=(298, 131, 311, 142)
# 프레임 4923: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(231, 120, 253, 134)
#
# 0: 384x640 3 cars, 210.0ms
# Speed: 1.2ms preprocess, 210.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4925: 감지 - 클래스=car, 신뢰도=0.80, 좌표=(379, 127, 422, 158)
# 프레임 4925: 감지 - 클래스=car, 신뢰도=0.74, 좌표=(280, 134, 304, 151)
# 프레임 4925: 감지 - 클래스=car, 신뢰도=0.57, 좌표=(314, 129, 355, 163)
#
# 0: 384x640 4 cars, 262.8ms
# Speed: 1.2ms preprocess, 262.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4927: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(379, 129, 422, 160)
# 프레임 4927: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(281, 136, 304, 153)
# 프레임 4927: 감지 - 클래스=car, 신뢰도=0.61, 좌표=(314, 132, 354, 165)
# 프레임 4927: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(225, 125, 243, 138)
#
# 0: 384x640 4 cars, 216.2ms
# Speed: 1.3ms preprocess, 216.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4929: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(379, 133, 423, 165)
# 프레임 4929: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(280, 140, 304, 158)
# 프레임 4929: 감지 - 클래스=car, 신뢰도=0.50, 좌표=(314, 136, 354, 169)
# 프레임 4929: 감지 - 클래스=car, 신뢰도=0.37, 좌표=(221, 129, 240, 142)
#
# 0: 384x640 4 cars, 263.8ms
# Speed: 1.2ms preprocess, 263.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4931: 감지 - 클래스=car, 신뢰도=0.74, 좌표=(281, 146, 304, 163)
# 프레임 4931: 감지 - 클래스=car, 신뢰도=0.70, 좌표=(380, 137, 422, 169)
# 프레임 4931: 감지 - 클래스=car, 신뢰도=0.69, 좌표=(314, 141, 353, 174)
# 프레임 4931: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(349, 146, 360, 154)
#
# 0: 384x640 5 cars, 214.7ms
# Speed: 1.2ms preprocess, 214.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4933: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(379, 141, 422, 172)
# 프레임 4933: 감지 - 클래스=car, 신뢰도=0.73, 좌표=(281, 150, 304, 167)
# 프레임 4933: 감지 - 클래스=car, 신뢰도=0.63, 좌표=(314, 145, 354, 178)
# 프레임 4933: 감지 - 클래스=car, 신뢰도=0.32, 좌표=(298, 149, 311, 160)
# 프레임 4933: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(356, 143, 369, 156)
#
# 0: 384x640 6 cars, 273.9ms
# Speed: 1.2ms preprocess, 273.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4935: 감지 - 클래스=car, 신뢰도=0.81, 좌표=(379, 143, 421, 174)
# 프레임 4935: 감지 - 클래스=car, 신뢰도=0.78, 좌표=(280, 153, 304, 170)
# 프레임 4935: 감지 - 클래스=car, 신뢰도=0.67, 좌표=(314, 148, 354, 180)
# 프레임 4935: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(348, 153, 359, 162)
# 프레임 4935: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(355, 146, 368, 158)
# 프레임 4935: 감지 - 클래스=car, 신뢰도=0.32, 좌표=(239, 148, 249, 156)
#
# 0: 384x640 6 cars, 219.1ms
# Speed: 1.3ms preprocess, 219.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4937: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(379, 147, 422, 177)
# 프레임 4937: 감지 - 클래스=car, 신뢰도=0.74, 좌표=(281, 156, 304, 173)
# 프레임 4937: 감지 - 클래스=car, 신뢰도=0.56, 좌표=(314, 150, 353, 183)
# 프레임 4937: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(234, 151, 247, 159)
# 프레임 4937: 감지 - 클래스=car, 신뢰도=0.32, 좌표=(348, 155, 359, 164)
# 프레임 4937: 감지 - 클래스=car, 신뢰도=0.32, 좌표=(298, 155, 311, 166)
#
# 0: 384x640 7 cars, 211.5ms
# Speed: 52.9ms preprocess, 211.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4939: 감지 - 클래스=car, 신뢰도=0.82, 좌표=(379, 149, 422, 180)
# 프레임 4939: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(281, 158, 305, 175)
# 프레임 4939: 감지 - 클래스=car, 신뢰도=0.45, 좌표=(314, 152, 353, 184)
# 프레임 4939: 감지 - 클래스=car, 신뢰도=0.41, 좌표=(230, 153, 244, 161)
# 프레임 4939: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(348, 158, 359, 166)
# 프레임 4939: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(355, 150, 369, 164)
# 프레임 4939: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(298, 157, 311, 168)
#
# 0: 384x640 6 cars, 213.5ms
# Speed: 1.2ms preprocess, 213.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4941: 감지 - 클래스=car, 신뢰도=0.82, 좌표=(380, 151, 422, 181)
# 프레임 4941: 감지 - 클래스=car, 신뢰도=0.74, 좌표=(281, 161, 305, 177)
# 프레임 4941: 감지 - 클래스=car, 신뢰도=0.63, 좌표=(314, 155, 352, 186)
# 프레임 4941: 감지 - 클래스=car, 신뢰도=0.46, 좌표=(348, 160, 359, 169)
# 프레임 4941: 감지 - 클래스=car, 신뢰도=0.35, 좌표=(228, 156, 244, 163)
# 프레임 4941: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(354, 154, 368, 166)
#
# 0: 384x640 5 cars, 265.3ms
# Speed: 1.2ms preprocess, 265.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4943: 감지 - 클래스=car, 신뢰도=0.82, 좌표=(379, 152, 422, 182)
# 프레임 4943: 감지 - 클래스=car, 신뢰도=0.75, 좌표=(281, 161, 304, 178)
# 프레임 4943: 감지 - 클래스=car, 신뢰도=0.69, 좌표=(314, 156, 352, 187)
# 프레임 4943: 감지 - 클래스=car, 신뢰도=0.45, 좌표=(348, 162, 359, 170)
# 프레임 4943: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(355, 154, 368, 167)
#
# 0: 384x640 5 cars, 217.3ms
# Speed: 1.3ms preprocess, 217.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4945: 감지 - 클래스=car, 신뢰도=0.79, 좌표=(380, 152, 422, 183)
# 프레임 4945: 감지 - 클래스=car, 신뢰도=0.73, 좌표=(281, 162, 304, 179)
# 프레임 4945: 감지 - 클래스=car, 신뢰도=0.63, 좌표=(314, 162, 352, 188)
# 프레임 4945: 감지 - 클래스=car, 신뢰도=0.37, 좌표=(347, 162, 359, 170)
# 프레임 4945: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(355, 155, 368, 167)
#
# 0: 384x640 5 cars, 270.1ms
# Speed: 1.1ms preprocess, 270.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4947: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(380, 153, 421, 183)
# 프레임 4947: 감지 - 클래스=car, 신뢰도=0.71, 좌표=(281, 162, 304, 179)
# 프레임 4947: 감지 - 클래스=car, 신뢰도=0.67, 좌표=(313, 156, 352, 188)
# 프레임 4947: 감지 - 클래스=car, 신뢰도=0.46, 좌표=(347, 162, 359, 171)
# 프레임 4947: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(216, 157, 243, 165)
#
# 0: 384x640 4 cars, 212.1ms
# Speed: 1.1ms preprocess, 212.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4949: 감지 - 클래스=car, 신뢰도=0.76, 좌표=(380, 153, 422, 184)
# 프레임 4949: 감지 - 클래스=car, 신뢰도=0.70, 좌표=(281, 163, 304, 179)
# 프레임 4949: 감지 - 클래스=car, 신뢰도=0.63, 좌표=(314, 157, 353, 189)
# 프레임 4949: 감지 - 클래스=car, 신뢰도=0.44, 좌표=(347, 162, 359, 171)
#
# 0: 384x640 4 cars, 266.6ms
# Speed: 1.2ms preprocess, 266.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4951: 감지 - 클래스=car, 신뢰도=0.81, 좌표=(380, 154, 421, 184)
# 프레임 4951: 감지 - 클래스=car, 신뢰도=0.73, 좌표=(281, 163, 304, 180)
# 프레임 4951: 감지 - 클래스=car, 신뢰도=0.60, 좌표=(313, 157, 352, 189)
# 프레임 4951: 감지 - 클래스=car, 신뢰도=0.36, 좌표=(347, 163, 358, 172)
#
# 0: 384x640 5 cars, 1 bus, 217.7ms
# Speed: 1.2ms preprocess, 217.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4953: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(379, 154, 422, 184)
# 프레임 4953: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(281, 163, 304, 180)
# 프레임 4953: 감지 - 클래스=car, 신뢰도=0.67, 좌표=(312, 157, 351, 189)
# 프레임 4953: 감지 - 클래스=car, 신뢰도=0.38, 좌표=(347, 162, 358, 172)
# 프레임 4953: 감지 - 클래스=car, 신뢰도=0.34, 좌표=(202, 158, 228, 167)
# 프레임 4953: 감지 - 클래스=bus, 신뢰도=0.31, 좌표=(73, 142, 169, 171)
#
# 0: 384x640 4 cars, 1 bus, 274.1ms
# Speed: 1.2ms preprocess, 274.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4955: 감지 - 클래스=car, 신뢰도=0.77, 좌표=(379, 153, 421, 183)
# 프레임 4955: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(281, 163, 303, 180)
# 프레임 4955: 감지 - 클래스=car, 신뢰도=0.64, 좌표=(312, 156, 351, 189)
# 프레임 4955: 감지 - 클래스=car, 신뢰도=0.42, 좌표=(346, 162, 358, 172)
# 프레임 4955: 감지 - 클래스=bus, 신뢰도=0.38, 좌표=(57, 139, 155, 173)
#
# 0: 384x640 5 cars, 218.7ms
# Speed: 1.3ms preprocess, 218.7ms inference, 54.2ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4957: 감지 - 클래스=car, 신뢰도=0.82, 좌표=(378, 151, 422, 182)
# 프레임 4957: 감지 - 클래스=car, 신뢰도=0.72, 좌표=(280, 162, 303, 179)
# 프레임 4957: 감지 - 클래스=car, 신뢰도=0.55, 좌표=(312, 155, 351, 187)
# 프레임 4957: 감지 - 클래스=car, 신뢰도=0.48, 좌표=(346, 161, 358, 171)
# 프레임 4957: 감지 - 클래스=car, 신뢰도=0.38, 좌표=(189, 156, 223, 167)
#
# 0: 384x640 5 cars, 1 airplane, 1 truck, 213.2ms
# Speed: 1.3ms preprocess, 213.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 프레임 4959: 감지 - 클래스=car, 신뢰도=0.83, 좌표=(379, 151, 422, 181)
# 프레임 4959: 감지 - 클래스=car, 신뢰도=0.73, 좌표=(281, 161, 303, 178)
# 프레임 4959: 감지 - 클래스=car, 신뢰도=0.56, 좌표=(312, 154, 350, 186)
# 프레임 4959: 감지 - 클래스=car, 신뢰도=0.47, 좌표=(346, 160, 358, 170)
# 프레임 4959: 감지 - 클래스=truck, 신뢰도=0.41, 좌표=(311, 154, 349, 187)
# 프레임 4959: 감지 - 클래스=car, 신뢰도=0.31, 좌표=(355, 157, 366, 167)
# 처리된 비디오가 /content/output_video.mp4에 저장되었습니다.
# 처리된 비디오 다운로드 중...
